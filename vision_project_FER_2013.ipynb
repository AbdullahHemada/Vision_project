# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahHemada/Vision_project/blob/main/vision_project_FER_2013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("msambare/fer2013")
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.

# %%
# import libraries
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization #for CNN model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix  #for training report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential   #for training model
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import random
import cv2
import os

# %% [markdown]
# #Visualizing Data

# %%
train_path = os.path.join(path, 'train')
test_path = os.path.join(path, 'test')

# %%
classes=os.listdir(train_path)
print("Existing Classes :",classes)

plt.figure(figsize=(15,5))
for index,emotion in enumerate(classes):
  emotion_path=os.path.join(train_path,emotion)
  rand_image=random.choice(os.listdir(emotion_path))
  image_path=os.path.join(emotion_path,rand_image)
  image=cv2.imread(image_path)
  img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  plt.subplot(1, len(classes), index+1)
  plt.imshow(img)
  plt.title(emotion)
  plt.axis("off")

plt.tight_layout()
plt.show()


# Function to count images per class in a given path
def count_images_per_class(base_path, classes):
    counts = {}
    for emotion in classes:
        emotion_dir = os.path.join(base_path, emotion)
        if os.path.exists(emotion_dir):
            counts[emotion] = len(os.listdir(emotion_dir))
        else:
            counts[emotion] = 0
    return counts

# Count images for training set
train_counts = count_images_per_class(train_path, classes)
train_df = pd.DataFrame.from_dict(train_counts, orient='index', columns=['Train Count'])

# Count images for testing set
test_counts = count_images_per_class(test_path, classes)
test_df = pd.DataFrame.from_dict(test_counts, orient='index', columns=['Test Count'])

# Display the summary in a formatted way
print("train_counts: \n")
display(train_df)
print("\ntest_counts:")
display(test_df)

print("total train image :",train_df['Train Count'].sum())
print("total test image :",test_df['Test Count'].sum())
# Out:
# Existing Classes : ['surprise', 'fear', 'angry', 'neutral', 'sad', 'disgust', 'happy']
# train_counts:
#           Train Count
# surprise         3171
# fear             4097
# angry            3995
# neutral          4965
# sad              4830
# disgust           436
# happy            7215
# test_counts:
#           Test Count
# surprise         831
# fear            1024
# angry            958
# neutral         1233
# sad             1247
# disgust          111
# happy           1774
# total train image : 28709
# total test image : 7178

# %% [markdown]
# # Images shape

# %%
print(f"Image dimensions: {img.shape}") # Output from the previously executed cell
# Out:
# Image dimensions: (48, 48, 3)

# %% [markdown]
# ### Dataset Class Distribution Visualization

# %%
# Visualize class distribution for training set
plt.figure(figsize=(12, 6))
sns.barplot(x=train_df.index, y='Train Count', data=train_df, palette='viridis', hue=train_df.index, legend=False)
plt.title('Training Data: Number of Images per Emotion Class')
plt.xlabel('Emotion')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Visualize class distribution for testing set
plt.figure(figsize=(12, 6))
sns.barplot(x=test_df.index, y='Test Count', data=test_df, palette='plasma', hue=test_df.index, legend=False)
plt.title('Test Data: Number of Images per Emotion Class')
plt.xlabel('Emotion')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Data Augmentation

# %%
# Image parameters
IMG_SIZE = (48, 48)
BATCH_SIZE = 128
EPOCHS = 100
NUM_CLASSES = 7

# %%
# Data generators with augmentation for trainingt
train_datagen=ImageDataGenerator(
    rescale=1./255,       #Normalization
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2  # 20% for validation
)

# %%
# Data generators with Normalizing for testing
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Loading training data
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 22968 images belonging to 7 classes.

# %%
# Loading validation data
val_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 5741 images belonging to 7 classes.

# %%
# Loading test data
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=IMG_SIZE,
    color_mode='grayscale', # Changed from 'grayscale' to 'rgb'
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Take one image
images, labels = next(train_generator)
img = images[0]

# Plot original + augmented versions
plt.figure(figsize=(12, 6))
plt.subplot(2, 5, 1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis('off')

# Show 8 augmented versions
for i in range(8):
    augmented_img = train_datagen.random_transform(img)
    plt.subplot(2, 5, i + 2)
    plt.imshow(augmented_img, cmap='gray')
    plt.title(f"Aug {i+1}")
    plt.axis('off')

plt.suptitle("Original Image vs Augmented Versions", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Building the CNN Model

# %%
# Building a deeper CNN model
model = Sequential([
    # Block 1
    Conv2D(64, (3, 3), padding='same', activation='relu',input_shape=(48, 48, 1)),
    BatchNormalization(),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Block 2
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Block 3
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Block 4
    Conv2D(512, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(512, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

   # Dense layers
    Flatten(),
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #Optimizer

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Create a clone of the model for SGD optimizer
from tensorflow.keras.models import clone_model

model_SGD = clone_model(model)
model_SGD.set_weights(model.get_weights())

model_SGD.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Create a clone of the model for Adagrad optimizer
from tensorflow.keras.models import clone_model

model_Adagrad = clone_model(model)
model_Adagrad.set_weights(model.get_weights())

model_Adagrad.compile(
    optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.01),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 6, 6, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,946,055 (37.94 MB)
#  Trainable params: 9,939,143 (37.91 MB)
#  Non-trainable params: 6,912 (27.00 KB)

# %%
#early stop to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# %%
# We use class weights to address class imbalance since some classes have fewer samples.

# 1. Get the class indices and counts from the training generator
class_lable=train_generator.classes
num_classes=train_generator.num_classes

# 2. Compute class weights
class_weights_array=class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(class_lable),y=class_lable)

class_weights = dict(enumerate(class_weights_array))
print("Calculated Class Weights:", class_weights)
# Out:
# Calculated Class Weights: {0: np.float64(1.0266404434114071), 1: np.float64(9.401555464592715), 2: np.float64(1.0009587727708533), 3: np.float64(0.5684585684585685), 4: np.float64(0.826068191627104), 5: np.float64(0.8491570541259982), 6: np.float64(1.2933160650937552)}

# %% [markdown]
# #Model Training

# %%
history=model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 166s 776ms/step - accuracy: 0.1560 - loss: 2.8898 - val_accuracy: 0.1730 - val_loss: 3.9313 - learning_rate: 0.0010
# Epoch 2/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.1787 - loss: 2.1547 - val_accuracy: 0.1585 - val_loss: 1.9800 - learning_rate: 0.0010
# Epoch 3/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.1953 - loss: 1.9908 - val_accuracy: 0.1636 - val_loss: 1.9076 - learning_rate: 0.0010
# Epoch 4/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.2441 - loss: 1.8715 - val_accuracy: 0.2264 - val_loss: 2.0271 - learning_rate: 0.0010
# Epoch 5/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.3048 - loss: 1.7841 - val_accuracy: 0.3052 - val_loss: 1.7607 - learning_rate: 0.0010
# Epoch 6/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - accuracy: 0.3522 - loss: 1.7096 - val_accuracy: 0.3534 - val_loss: 1.6605 - learning_rate: 0.0010
# Epoch 7/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.3916 - loss: 1.5851 - val_accuracy: 0.1667 - val_loss: 7.6836 - learning_rate: 0.0010
# Epoch 8/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.4149 - loss: 1.5644 - val_accuracy: 0.3379 - val_loss: 1.7205 - learning_rate: 0.0010
# Epoch 9/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.4235 - loss: 1.5237 - val_accuracy: 0.4020 - val_loss: 1.5243 - learning_rate: 0.0010
# Epoch 10/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.4450 - loss: 1.4279 - val_accuracy: 0.4113 - val_loss: 1.5022 - learning_rate: 0.0010
# Epoch 11/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.4606 - loss: 1.3892 - val_accuracy: 0.4271 - val_loss: 1.4955 - learning_rate: 0.0010
# Epoch 12/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.4766 - loss: 1.3512 - val_accuracy: 0.4065 - val_loss: 1.5322 - learning_rate: 0.0010
# Epoch 13/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.4802 - loss: 1.3413 - val_accuracy: 0.4308 - val_loss: 1.4542 - learning_rate: 0.0010
# Epoch 14/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - accuracy: 0.5055 - loss: 1.2778 - val_accuracy: 0.4747 - val_loss: 1.3930 - learning_rate: 0.0010
# Epoch 15/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.5102 - loss: 1.2615 - val_accuracy: 0.4593 - val_loss: 1.4268 - learning_rate: 0.0010
# Epoch 16/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 222ms/step - accuracy: 0.5246 - loss: 1.2376 - val_accuracy: 0.5217 - val_loss: 1.2637 - learning_rate: 0.0010
# Epoch 17/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.5358 - loss: 1.1939 - val_accuracy: 0.4522 - val_loss: 1.5253 - learning_rate: 0.0010
# Epoch 18/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.5379 - loss: 1.1897 - val_accuracy: 0.4943 - val_loss: 1.3333 - learning_rate: 0.0010
# Epoch 19/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 41s 225ms/step - accuracy: 0.5465 - loss: 1.1785 - val_accuracy: 0.5422 - val_loss: 1.2000 - learning_rate: 0.0010
# Epoch 20/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.5549 - loss: 1.1488 - val_accuracy: 0.5246 - val_loss: 1.2784 - learning_rate: 0.0010
# Epoch 21/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.5547 - loss: 1.1281 - val_accuracy: 0.5227 - val_loss: 1.2668 - learning_rate: 0.0010
# Epoch 22/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.5596 - loss: 1.1137 - val_accuracy: 0.5492 - val_loss: 1.1982 - learning_rate: 0.0010
# Epoch 23/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.5690 - loss: 1.0816 - val_accuracy: 0.5107 - val_loss: 1.3407 - learning_rate: 0.0010
# Epoch 24/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.5713 - loss: 1.0823 - val_accuracy: 0.5046 - val_loss: 1.2888 - learning_rate: 0.0010
# Epoch 25/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.5815 - loss: 1.0688 - val_accuracy: 0.4886 - val_loss: 1.3302 - learning_rate: 0.0010
# Epoch 26/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.5822 - loss: 1.0667 - val_accuracy: 0.5367 - val_loss: 1.2166 - learning_rate: 0.0010
# Epoch 27/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.5920 - loss: 1.0345 - val_accuracy: 0.5530 - val_loss: 1.2166 - learning_rate: 0.0010
# Epoch 28/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.6135 - loss: 0.9881 - val_accuracy: 0.5978 - val_loss: 1.0579 - learning_rate: 2.0000e-04
# Epoch 29/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.6230 - loss: 0.9355 - val_accuracy: 0.6058 - val_loss: 1.0371 - learning_rate: 2.0000e-04
# Epoch 30/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.6334 - loss: 0.8978 - val_accuracy: 0.6187 - val_loss: 1.0251 - learning_rate: 2.0000e-04
# Epoch 31/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6416 - loss: 0.8952 - val_accuracy: 0.6147 - val_loss: 1.0216 - learning_rate: 2.0000e-04
# Epoch 32/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.6446 - loss: 0.8675 - val_accuracy: 0.6145 - val_loss: 1.0286 - learning_rate: 2.0000e-04
# Epoch 33/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.6399 - loss: 0.8965 - val_accuracy: 0.6060 - val_loss: 1.0312 - learning_rate: 2.0000e-04
# Epoch 34/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.6465 - loss: 0.8664 - val_accuracy: 0.6204 - val_loss: 1.0163 - learning_rate: 2.0000e-04
# Epoch 35/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6578 - loss: 0.8423 - val_accuracy: 0.6258 - val_loss: 1.0079 - learning_rate: 2.0000e-04
# Epoch 36/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.6642 - loss: 0.8256 - val_accuracy: 0.6260 - val_loss: 1.0058 - learning_rate: 2.0000e-04
# Epoch 37/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.6663 - loss: 0.8204 - val_accuracy: 0.6117 - val_loss: 1.0316 - learning_rate: 2.0000e-04
# Epoch 38/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.6601 - loss: 0.8331 - val_accuracy: 0.6316 - val_loss: 0.9975 - learning_rate: 2.0000e-04
# Epoch 39/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6668 - loss: 0.8177 - val_accuracy: 0.6379 - val_loss: 0.9932 - learning_rate: 2.0000e-04
# Epoch 40/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6748 - loss: 0.8111 - val_accuracy: 0.6361 - val_loss: 0.9990 - learning_rate: 2.0000e-04
# Epoch 41/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.6699 - loss: 0.8143 - val_accuracy: 0.6292 - val_loss: 1.0059 - learning_rate: 2.0000e-04
# Epoch 42/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6761 - loss: 0.7923 - val_accuracy: 0.6180 - val_loss: 1.0573 - learning_rate: 2.0000e-04
# Epoch 43/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.6763 - loss: 0.7924 - val_accuracy: 0.6272 - val_loss: 1.0239 - learning_rate: 2.0000e-04
# Epoch 44/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.6789 - loss: 0.7810 - val_accuracy: 0.6274 - val_loss: 1.0055 - learning_rate: 2.0000e-04
# Epoch 45/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.6827 - loss: 0.7703 - val_accuracy: 0.6340 - val_loss: 0.9994 - learning_rate: 4.0000e-05
# Epoch 46/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6858 - loss: 0.7509 - val_accuracy: 0.6316 - val_loss: 0.9814 - learning_rate: 4.0000e-05
# Epoch 47/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.6982 - loss: 0.7384 - val_accuracy: 0.6387 - val_loss: 0.9846 - learning_rate: 4.0000e-05
# Epoch 48/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6946 - loss: 0.7462 - val_accuracy: 0.6356 - val_loss: 0.9810 - learning_rate: 4.0000e-05
# Epoch 49/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7002 - loss: 0.7291 - val_accuracy: 0.6372 - val_loss: 0.9780 - learning_rate: 4.0000e-05
# Epoch 50/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.6994 - loss: 0.7357 - val_accuracy: 0.6358 - val_loss: 0.9904 - learning_rate: 4.0000e-05
# Epoch 51/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 223ms/step - accuracy: 0.6969 - loss: 0.7289 - val_accuracy: 0.6419 - val_loss: 0.9857 - learning_rate: 4.0000e-05
# Epoch 52/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7051 - loss: 0.7181 - val_accuracy: 0.6422 - val_loss: 0.9884 - learning_rate: 4.0000e-05
# Epoch 53/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7032 - loss: 0.7252 - val_accuracy: 0.6365 - val_loss: 0.9865 - learning_rate: 4.0000e-05
# Epoch 54/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7064 - loss: 0.7084 - val_accuracy: 0.6398 - val_loss: 0.9951 - learning_rate: 4.0000e-05
# Epoch 55/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.6983 - loss: 0.7131 - val_accuracy: 0.6351 - val_loss: 1.0020 - learning_rate: 8.0000e-06
# Epoch 56/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7080 - loss: 0.7228 - val_accuracy: 0.6426 - val_loss: 0.9934 - learning_rate: 8.0000e-06
# Epoch 57/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7087 - loss: 0.7183 - val_accuracy: 0.6398 - val_loss: 0.9872 - learning_rate: 8.0000e-06
# Epoch 58/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7038 - loss: 0.7114 - val_accuracy: 0.6434 - val_loss: 0.9943 - learning_rate: 8.0000e-06
# Epoch 59/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7028 - loss: 0.7169 - val_accuracy: 0.6398 - val_loss: 0.9882 - learning_rate: 8.0000e-06
# Epoch 60/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - accuracy: 0.7038 - loss: 0.7145 - val_accuracy: 0.6393 - val_loss: 0.9974 - learning_rate: 1.6000e-06
# Epoch 61/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7035 - loss: 0.7180 - val_accuracy: 0.6431 - val_loss: 0.9803 - learning_rate: 1.6000e-06
# Epoch 62/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7033 - loss: 0.7191 - val_accuracy: 0.6436 - val_loss: 0.9866 - learning_rate: 1.6000e-06
# Epoch 63/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 43s 240ms/step - accuracy: 0.7071 - loss: 0.7001 - val_accuracy: 0.6431 - val_loss: 0.9912 - learning_rate: 1.6000e-06
# Epoch 64/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7004 - loss: 0.7206 - val_accuracy: 0.6360 - val_loss: 0.9979 - learning_rate: 1.6000e-06
# Epoch 65/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7056 - loss: 0.7125 - val_accuracy: 0.6389 - val_loss: 0.9848 - learning_rate: 1.0000e-06
# Epoch 66/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7054 - loss: 0.7275 - val_accuracy: 0.6468 - val_loss: 0.9787 - learning_rate: 1.0000e-06
# Epoch 67/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7080 - loss: 0.7097 - val_accuracy: 0.6386 - val_loss: 0.9927 - learning_rate: 1.0000e-06
# Epoch 68/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7007 - loss: 0.7178 - val_accuracy: 0.6407 - val_loss: 0.9825 - learning_rate: 1.0000e-06
# Epoch 69/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7086 - loss: 0.7047 - val_accuracy: 0.6436 - val_loss: 0.9846 - learning_rate: 1.0000e-06
# Epoch 70/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7125 - loss: 0.6940 - val_accuracy: 0.6422 - val_loss: 0.9899 - learning_rate: 1.0000e-06
# Epoch 71/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.6993 - loss: 0.7194 - val_accuracy: 0.6393 - val_loss: 0.9999 - learning_rate: 1.0000e-06
# Epoch 72/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7032 - loss: 0.7124 - val_accuracy: 0.6434 - val_loss: 0.9809 - learning_rate: 1.0000e-06
# Epoch 73/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7142 - loss: 0.7005 - val_accuracy: 0.6403 - val_loss: 0.9984 - learning_rate: 1.0000e-06
# Epoch 74/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7072 - loss: 0.7060 - val_accuracy: 0.6431 - val_loss: 0.9885 - learning_rate: 1.0000e-06
# Epoch 75/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7099 - loss: 0.7074 - val_accuracy: 0.6380 - val_loss: 0.9908 - learning_rate: 1.0000e-06
# Epoch 76/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7043 - loss: 0.7161 - val_accuracy: 0.6422 - val_loss: 0.9862 - learning_rate: 1.0000e-06
# Epoch 77/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7097 - loss: 0.7071 - val_accuracy: 0.6431 - val_loss: 0.9766 - learning_rate: 1.0000e-06
# Epoch 78/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.7114 - loss: 0.7013 - val_accuracy: 0.6474 - val_loss: 0.9815 - learning_rate: 1.0000e-06
# Epoch 79/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7021 - loss: 0.7048 - val_accuracy: 0.6469 - val_loss: 0.9877 - learning_rate: 1.0000e-06
# Epoch 80/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7115 - loss: 0.7039 - val_accuracy: 0.6415 - val_loss: 0.9811 - learning_rate: 1.0000e-06
# Epoch 81/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7144 - loss: 0.7007 - val_accuracy: 0.6415 - val_loss: 0.9896 - learning_rate: 1.0000e-06
# Epoch 82/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7096 - loss: 0.7029 - val_accuracy: 0.6389 - val_loss: 0.9842 - learning_rate: 1.0000e-06
# Epoch 83/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7054 - loss: 0.7111 - val_accuracy: 0.6396 - val_loss: 0.9920 - learning_rate: 1.0000e-06
# Epoch 84/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7124 - loss: 0.6981 - val_accuracy: 0.6422 - val_loss: 0.9837 - learning_rate: 1.0000e-06
# Epoch 85/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7077 - loss: 0.7140 - val_accuracy: 0.6391 - val_loss: 0.9923 - learning_rate: 1.0000e-06
# Epoch 86/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7156 - loss: 0.6961 - val_accuracy: 0.6372 - val_loss: 0.9923 - learning_rate: 1.0000e-06
# Epoch 87/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7101 - loss: 0.7040 - val_accuracy: 0.6450 - val_loss: 0.9878 - learning_rate: 1.0000e-06
# Epoch 88/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.7078 - loss: 0.7094 - val_accuracy: 0.6400 - val_loss: 0.9919 - learning_rate: 1.0000e-06
# Epoch 89/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7046 - loss: 0.7060 - val_accuracy: 0.6349 - val_loss: 0.9883 - learning_rate: 1.0000e-06
# Epoch 90/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7071 - loss: 0.7019 - val_accuracy: 0.6459 - val_loss: 0.9844 - learning_rate: 1.0000e-06
# Epoch 91/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7053 - loss: 0.7085 - val_accuracy: 0.6403 - val_loss: 0.9892 - learning_rate: 1.0000e-06
# Epoch 92/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7051 - loss: 0.7185 - val_accuracy: 0.6426 - val_loss: 0.9880 - learning_rate: 1.0000e-06
# Epoch 93/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7149 - loss: 0.6950 - val_accuracy: 0.6412 - val_loss: 0.9947 - learning_rate: 1.0000e-06
# Epoch 94/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7057 - loss: 0.7094 - val_accuracy: 0.6419 - val_loss: 0.9908 - learning_rate: 1.0000e-06
# Epoch 95/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7067 - loss: 0.7135 - val_accuracy: 0.6401 - val_loss: 0.9875 - learning_rate: 1.0000e-06
# Epoch 96/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7048 - loss: 0.7104 - val_accuracy: 0.6401 - val_loss: 0.9925 - learning_rate: 1.0000e-06
# Epoch 97/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7120 - loss: 0.7033 - val_accuracy: 0.6450 - val_loss: 0.9878 - learning_rate: 1.0000e-06
# Epoch 98/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7066 - loss: 0.7067 - val_accuracy: 0.6457 - val_loss: 0.9820 - learning_rate: 1.0000e-06
# Epoch 99/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - accuracy: 0.7075 - loss: 0.7044 - val_accuracy: 0.6380 - val_loss: 0.9936 - learning_rate: 1.0000e-06
# Epoch 100/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7121 - loss: 0.6981 - val_accuracy: 0.6401 - val_loss: 0.9934 - learning_rate: 1.0000e-06

# %%
#fit model with SGD optimizer
history_SGD=model_SGD.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 61s 273ms/step - accuracy: 0.6694 - loss: 0.8390 - val_accuracy: 0.6163 - val_loss: 1.0580 - learning_rate: 0.0100
# Epoch 2/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.6854 - loss: 0.7487 - val_accuracy: 0.5065 - val_loss: 1.3517 - learning_rate: 0.0100
# Epoch 3/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.6913 - loss: 0.7444 - val_accuracy: 0.6191 - val_loss: 1.0340 - learning_rate: 0.0100
# Epoch 4/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - accuracy: 0.6958 - loss: 0.7326 - val_accuracy: 0.6293 - val_loss: 1.0078 - learning_rate: 0.0100
# Epoch 5/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.6932 - loss: 0.7528 - val_accuracy: 0.6128 - val_loss: 1.0577 - learning_rate: 0.0100
# Epoch 6/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7009 - loss: 0.7268 - val_accuracy: 0.6417 - val_loss: 1.0044 - learning_rate: 0.0100
# Epoch 7/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.7032 - loss: 0.7163 - val_accuracy: 0.6337 - val_loss: 1.0091 - learning_rate: 0.0100
# Epoch 8/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7077 - loss: 0.7147 - val_accuracy: 0.6389 - val_loss: 1.0118 - learning_rate: 0.0100
# Epoch 9/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.6962 - loss: 0.7260 - val_accuracy: 0.6377 - val_loss: 1.0238 - learning_rate: 0.0100
# Epoch 10/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7045 - loss: 0.7138 - val_accuracy: 0.6177 - val_loss: 1.0495 - learning_rate: 0.0100
# Epoch 11/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7059 - loss: 0.7210 - val_accuracy: 0.6330 - val_loss: 1.0332 - learning_rate: 0.0100
# Epoch 12/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.6997 - loss: 0.7182 - val_accuracy: 0.6319 - val_loss: 1.0151 - learning_rate: 0.0020
# Epoch 13/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7031 - loss: 0.7215 - val_accuracy: 0.6340 - val_loss: 1.0051 - learning_rate: 0.0020
# Epoch 14/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.7039 - loss: 0.7130 - val_accuracy: 0.6386 - val_loss: 0.9960 - learning_rate: 0.0020
# Epoch 15/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7062 - loss: 0.7137 - val_accuracy: 0.6316 - val_loss: 1.0045 - learning_rate: 0.0020
# Epoch 16/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7041 - loss: 0.7084 - val_accuracy: 0.6447 - val_loss: 0.9945 - learning_rate: 0.0020
# Epoch 17/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7086 - loss: 0.7015 - val_accuracy: 0.6434 - val_loss: 0.9890 - learning_rate: 0.0020
# Epoch 18/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7019 - loss: 0.7236 - val_accuracy: 0.6422 - val_loss: 0.9961 - learning_rate: 0.0020
# Epoch 19/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7054 - loss: 0.7130 - val_accuracy: 0.6394 - val_loss: 0.9922 - learning_rate: 0.0020
# Epoch 20/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7081 - loss: 0.7058 - val_accuracy: 0.6394 - val_loss: 1.0023 - learning_rate: 0.0020
# Epoch 21/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7068 - loss: 0.7012 - val_accuracy: 0.6386 - val_loss: 1.0066 - learning_rate: 0.0020
# Epoch 22/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7045 - loss: 0.7112 - val_accuracy: 0.6417 - val_loss: 1.0023 - learning_rate: 0.0020
# Epoch 23/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7086 - loss: 0.7064 - val_accuracy: 0.6502 - val_loss: 0.9923 - learning_rate: 4.0000e-04
# Epoch 24/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7116 - loss: 0.7018 - val_accuracy: 0.6407 - val_loss: 0.9949 - learning_rate: 4.0000e-04
# Epoch 25/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7093 - loss: 0.6941 - val_accuracy: 0.6393 - val_loss: 0.9982 - learning_rate: 4.0000e-04
# Epoch 26/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.7113 - loss: 0.7100 - val_accuracy: 0.6440 - val_loss: 0.9920 - learning_rate: 4.0000e-04
# Epoch 27/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7062 - loss: 0.7125 - val_accuracy: 0.6389 - val_loss: 0.9992 - learning_rate: 4.0000e-04
# Epoch 28/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 214ms/step - accuracy: 0.7088 - loss: 0.7089 - val_accuracy: 0.6440 - val_loss: 0.9881 - learning_rate: 8.0000e-05
# Epoch 29/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7067 - loss: 0.7043 - val_accuracy: 0.6360 - val_loss: 1.0025 - learning_rate: 8.0000e-05
# Epoch 30/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 42s 234ms/step - accuracy: 0.7082 - loss: 0.6961 - val_accuracy: 0.6405 - val_loss: 0.9908 - learning_rate: 8.0000e-05
# Epoch 31/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 42s 232ms/step - accuracy: 0.7065 - loss: 0.7116 - val_accuracy: 0.6393 - val_loss: 0.9917 - learning_rate: 8.0000e-05
# Epoch 32/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7074 - loss: 0.7078 - val_accuracy: 0.6420 - val_loss: 0.9976 - learning_rate: 8.0000e-05
# Epoch 33/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7087 - loss: 0.7000 - val_accuracy: 0.6420 - val_loss: 0.9894 - learning_rate: 8.0000e-05
# Epoch 34/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7115 - loss: 0.7052 - val_accuracy: 0.6438 - val_loss: 0.9874 - learning_rate: 1.6000e-05
# Epoch 35/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - accuracy: 0.7097 - loss: 0.7050 - val_accuracy: 0.6366 - val_loss: 1.0014 - learning_rate: 1.6000e-05
# Epoch 36/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7086 - loss: 0.7068 - val_accuracy: 0.6370 - val_loss: 1.0004 - learning_rate: 1.6000e-05
# Epoch 37/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.7080 - loss: 0.7108 - val_accuracy: 0.6426 - val_loss: 0.9913 - learning_rate: 1.6000e-05
# Epoch 38/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7060 - loss: 0.7056 - val_accuracy: 0.6424 - val_loss: 0.9922 - learning_rate: 1.6000e-05
# Epoch 39/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7149 - loss: 0.7023 - val_accuracy: 0.6420 - val_loss: 0.9965 - learning_rate: 1.6000e-05
# Epoch 40/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7067 - loss: 0.7092 - val_accuracy: 0.6480 - val_loss: 0.9891 - learning_rate: 3.2000e-06
# Epoch 41/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7082 - loss: 0.7044 - val_accuracy: 0.6452 - val_loss: 0.9806 - learning_rate: 3.2000e-06
# Epoch 42/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7114 - loss: 0.6963 - val_accuracy: 0.6417 - val_loss: 0.9989 - learning_rate: 3.2000e-06
# Epoch 43/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7110 - loss: 0.6933 - val_accuracy: 0.6335 - val_loss: 0.9991 - learning_rate: 3.2000e-06
# Epoch 44/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.7134 - loss: 0.6891 - val_accuracy: 0.6450 - val_loss: 0.9929 - learning_rate: 3.2000e-06
# Epoch 45/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7091 - loss: 0.7104 - val_accuracy: 0.6481 - val_loss: 0.9844 - learning_rate: 3.2000e-06
# Epoch 46/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7067 - loss: 0.7062 - val_accuracy: 0.6403 - val_loss: 1.0004 - learning_rate: 3.2000e-06
# Epoch 47/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7123 - loss: 0.7021 - val_accuracy: 0.6445 - val_loss: 0.9862 - learning_rate: 1.0000e-06
# Epoch 48/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7106 - loss: 0.6997 - val_accuracy: 0.6349 - val_loss: 0.9999 - learning_rate: 1.0000e-06
# Epoch 49/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7067 - loss: 0.7083 - val_accuracy: 0.6422 - val_loss: 0.9918 - learning_rate: 1.0000e-06
# Epoch 50/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7091 - loss: 0.7062 - val_accuracy: 0.6393 - val_loss: 1.0020 - learning_rate: 1.0000e-06
# Epoch 51/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7027 - loss: 0.7264 - val_accuracy: 0.6452 - val_loss: 0.9863 - learning_rate: 1.0000e-06
# Epoch 52/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7021 - loss: 0.7068 - val_accuracy: 0.6384 - val_loss: 0.9924 - learning_rate: 1.0000e-06
# Epoch 53/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7073 - loss: 0.7096 - val_accuracy: 0.6377 - val_loss: 0.9937 - learning_rate: 1.0000e-06
# Epoch 54/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7015 - loss: 0.7096 - val_accuracy: 0.6420 - val_loss: 0.9868 - learning_rate: 1.0000e-06
# Epoch 55/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7091 - loss: 0.7023 - val_accuracy: 0.6358 - val_loss: 0.9851 - learning_rate: 1.0000e-06
# Epoch 56/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7174 - loss: 0.6989 - val_accuracy: 0.6438 - val_loss: 0.9856 - learning_rate: 1.0000e-06
# Epoch 57/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7016 - loss: 0.7210 - val_accuracy: 0.6422 - val_loss: 0.9953 - learning_rate: 1.0000e-06
# Epoch 58/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7092 - loss: 0.7104 - val_accuracy: 0.6419 - val_loss: 0.9996 - learning_rate: 1.0000e-06
# Epoch 59/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7084 - loss: 0.7000 - val_accuracy: 0.6426 - val_loss: 0.9910 - learning_rate: 1.0000e-06
# Epoch 60/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.7028 - loss: 0.7152 - val_accuracy: 0.6424 - val_loss: 0.9923 - learning_rate: 1.0000e-06
# Epoch 61/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7072 - loss: 0.7171 - val_accuracy: 0.6365 - val_loss: 1.0002 - learning_rate: 1.0000e-06
# Epoch 62/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7090 - loss: 0.7045 - val_accuracy: 0.6368 - val_loss: 0.9913 - learning_rate: 1.0000e-06
# Epoch 63/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7028 - loss: 0.7148 - val_accuracy: 0.6391 - val_loss: 1.0004 - learning_rate: 1.0000e-06
# Epoch 64/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7116 - loss: 0.7067 - val_accuracy: 0.6393 - val_loss: 0.9933 - learning_rate: 1.0000e-06
# Epoch 65/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7075 - loss: 0.7030 - val_accuracy: 0.6417 - val_loss: 0.9954 - learning_rate: 1.0000e-06
# Epoch 66/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7060 - loss: 0.7108 - val_accuracy: 0.6401 - val_loss: 0.9910 - learning_rate: 1.0000e-06
# Epoch 67/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7081 - loss: 0.7068 - val_accuracy: 0.6433 - val_loss: 0.9916 - learning_rate: 1.0000e-06
# Epoch 68/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7093 - loss: 0.7109 - val_accuracy: 0.6396 - val_loss: 1.0029 - learning_rate: 1.0000e-06
# Epoch 69/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7048 - loss: 0.7091 - val_accuracy: 0.6471 - val_loss: 0.9992 - learning_rate: 1.0000e-06
# Epoch 70/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7174 - loss: 0.6961 - val_accuracy: 0.6361 - val_loss: 1.0002 - learning_rate: 1.0000e-06
# Epoch 71/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7065 - loss: 0.7031 - val_accuracy: 0.6429 - val_loss: 0.9818 - learning_rate: 1.0000e-06
# Epoch 72/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7103 - loss: 0.7016 - val_accuracy: 0.6400 - val_loss: 0.9944 - learning_rate: 1.0000e-06
# Epoch 73/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7119 - loss: 0.7041 - val_accuracy: 0.6375 - val_loss: 0.9951 - learning_rate: 1.0000e-06
# Epoch 74/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7036 - loss: 0.7260 - val_accuracy: 0.6450 - val_loss: 0.9888 - learning_rate: 1.0000e-06
# Epoch 75/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7153 - loss: 0.6963 - val_accuracy: 0.6394 - val_loss: 0.9987 - learning_rate: 1.0000e-06
# Epoch 76/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7054 - loss: 0.6961 - val_accuracy: 0.6461 - val_loss: 0.9999 - learning_rate: 1.0000e-06
# Epoch 77/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7083 - loss: 0.7071 - val_accuracy: 0.6429 - val_loss: 0.9885 - learning_rate: 1.0000e-06
# Epoch 78/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7037 - loss: 0.7032 - val_accuracy: 0.6457 - val_loss: 0.9928 - learning_rate: 1.0000e-06
# Epoch 79/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7121 - loss: 0.6912 - val_accuracy: 0.6358 - val_loss: 0.9993 - learning_rate: 1.0000e-06
# Epoch 80/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7027 - loss: 0.7197 - val_accuracy: 0.6403 - val_loss: 0.9937 - learning_rate: 1.0000e-06
# Epoch 81/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7068 - loss: 0.7060 - val_accuracy: 0.6373 - val_loss: 0.9926 - learning_rate: 1.0000e-06
# Epoch 82/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7040 - loss: 0.7073 - val_accuracy: 0.6375 - val_loss: 1.0076 - learning_rate: 1.0000e-06
# Epoch 83/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7043 - loss: 0.7144 - val_accuracy: 0.6422 - val_loss: 0.9970 - learning_rate: 1.0000e-06
# Epoch 84/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7114 - loss: 0.7001 - val_accuracy: 0.6420 - val_loss: 0.9961 - learning_rate: 1.0000e-06
# Epoch 85/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7081 - loss: 0.7093 - val_accuracy: 0.6380 - val_loss: 0.9936 - learning_rate: 1.0000e-06
# Epoch 86/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7143 - loss: 0.6895 - val_accuracy: 0.6366 - val_loss: 0.9991 - learning_rate: 1.0000e-06
# Epoch 87/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7077 - loss: 0.7099 - val_accuracy: 0.6398 - val_loss: 0.9869 - learning_rate: 1.0000e-06
# Epoch 88/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7081 - loss: 0.7043 - val_accuracy: 0.6478 - val_loss: 0.9938 - learning_rate: 1.0000e-06
# Epoch 89/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7117 - loss: 0.7048 - val_accuracy: 0.6370 - val_loss: 0.9905 - learning_rate: 1.0000e-06
# Epoch 90/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7076 - loss: 0.7031 - val_accuracy: 0.6445 - val_loss: 0.9928 - learning_rate: 1.0000e-06
# Epoch 91/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7048 - loss: 0.7147 - val_accuracy: 0.6434 - val_loss: 0.9940 - learning_rate: 1.0000e-06

# %%
#fit model with Adagrad optimizer
history_Adagrad=model_Adagrad.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 64s 279ms/step - accuracy: 0.7016 - loss: 0.7387 - val_accuracy: 0.6246 - val_loss: 1.0244 - learning_rate: 0.0100
# Epoch 2/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7012 - loss: 0.7295 - val_accuracy: 0.6450 - val_loss: 0.9843 - learning_rate: 0.0100
# Epoch 3/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7054 - loss: 0.7035 - val_accuracy: 0.6387 - val_loss: 1.0017 - learning_rate: 0.0100
# Epoch 4/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7064 - loss: 0.7065 - val_accuracy: 0.6290 - val_loss: 1.0093 - learning_rate: 0.0100
# Epoch 5/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7079 - loss: 0.7131 - val_accuracy: 0.6363 - val_loss: 1.0067 - learning_rate: 0.0100
# Epoch 6/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7066 - loss: 0.7065 - val_accuracy: 0.6342 - val_loss: 1.0044 - learning_rate: 0.0100
# Epoch 7/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7160 - loss: 0.6979 - val_accuracy: 0.6393 - val_loss: 1.0018 - learning_rate: 0.0100
# Epoch 8/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7087 - loss: 0.7121 - val_accuracy: 0.6366 - val_loss: 1.0056 - learning_rate: 0.0020
# Epoch 9/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7103 - loss: 0.6974 - val_accuracy: 0.6403 - val_loss: 0.9985 - learning_rate: 0.0020
# Epoch 10/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7112 - loss: 0.6908 - val_accuracy: 0.6393 - val_loss: 0.9998 - learning_rate: 0.0020
# Epoch 11/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 41s 226ms/step - accuracy: 0.7086 - loss: 0.7085 - val_accuracy: 0.6389 - val_loss: 0.9974 - learning_rate: 0.0020
# Epoch 12/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7123 - loss: 0.6980 - val_accuracy: 0.6445 - val_loss: 0.9952 - learning_rate: 0.0020
# Epoch 13/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7157 - loss: 0.6894 - val_accuracy: 0.6426 - val_loss: 0.9998 - learning_rate: 4.0000e-04
# Epoch 14/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7162 - loss: 0.6924 - val_accuracy: 0.6377 - val_loss: 0.9960 - learning_rate: 4.0000e-04
# Epoch 15/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7135 - loss: 0.6931 - val_accuracy: 0.6405 - val_loss: 1.0049 - learning_rate: 4.0000e-04
# Epoch 16/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.7123 - loss: 0.6964 - val_accuracy: 0.6394 - val_loss: 1.0001 - learning_rate: 4.0000e-04
# Epoch 17/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7147 - loss: 0.6912 - val_accuracy: 0.6394 - val_loss: 1.0012 - learning_rate: 4.0000e-04
# Epoch 18/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7089 - loss: 0.6997 - val_accuracy: 0.6393 - val_loss: 0.9954 - learning_rate: 8.0000e-05
# Epoch 19/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7143 - loss: 0.6891 - val_accuracy: 0.6403 - val_loss: 1.0029 - learning_rate: 8.0000e-05
# Epoch 20/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7133 - loss: 0.6895 - val_accuracy: 0.6459 - val_loss: 0.9972 - learning_rate: 8.0000e-05
# Epoch 21/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 211ms/step - accuracy: 0.7104 - loss: 0.7002 - val_accuracy: 0.6351 - val_loss: 1.0019 - learning_rate: 8.0000e-05
# Epoch 22/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7030 - loss: 0.7134 - val_accuracy: 0.6393 - val_loss: 1.0029 - learning_rate: 8.0000e-05
# Epoch 23/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.7121 - loss: 0.7019 - val_accuracy: 0.6398 - val_loss: 1.0043 - learning_rate: 1.6000e-05
# Epoch 24/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7073 - loss: 0.6919 - val_accuracy: 0.6349 - val_loss: 1.0018 - learning_rate: 1.6000e-05
# Epoch 25/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7128 - loss: 0.6979 - val_accuracy: 0.6363 - val_loss: 0.9988 - learning_rate: 1.6000e-05
# Epoch 26/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7106 - loss: 0.6964 - val_accuracy: 0.6405 - val_loss: 0.9994 - learning_rate: 1.6000e-05
# Epoch 27/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7116 - loss: 0.6986 - val_accuracy: 0.6370 - val_loss: 0.9942 - learning_rate: 1.6000e-05
# Epoch 28/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7141 - loss: 0.6959 - val_accuracy: 0.6436 - val_loss: 0.9944 - learning_rate: 3.2000e-06
# Epoch 29/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7071 - loss: 0.7050 - val_accuracy: 0.6353 - val_loss: 1.0060 - learning_rate: 3.2000e-06
# Epoch 30/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7088 - loss: 0.7114 - val_accuracy: 0.6488 - val_loss: 0.9898 - learning_rate: 3.2000e-06
# Epoch 31/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7133 - loss: 0.6817 - val_accuracy: 0.6401 - val_loss: 0.9955 - learning_rate: 3.2000e-06
# Epoch 32/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7144 - loss: 0.7007 - val_accuracy: 0.6403 - val_loss: 1.0002 - learning_rate: 3.2000e-06
# Epoch 33/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7172 - loss: 0.6845 - val_accuracy: 0.6443 - val_loss: 0.9992 - learning_rate: 1.0000e-06
# Epoch 34/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7119 - loss: 0.6911 - val_accuracy: 0.6400 - val_loss: 1.0054 - learning_rate: 1.0000e-06
# Epoch 35/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7093 - loss: 0.6926 - val_accuracy: 0.6462 - val_loss: 0.9911 - learning_rate: 1.0000e-06
# Epoch 36/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7088 - loss: 0.6936 - val_accuracy: 0.6426 - val_loss: 1.0001 - learning_rate: 1.0000e-06
# Epoch 37/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 216ms/step - accuracy: 0.7067 - loss: 0.6995 - val_accuracy: 0.6353 - val_loss: 1.0069 - learning_rate: 1.0000e-06
# Epoch 38/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 210ms/step - accuracy: 0.7145 - loss: 0.6955 - val_accuracy: 0.6403 - val_loss: 0.9957 - learning_rate: 1.0000e-06
# Epoch 39/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7140 - loss: 0.6990 - val_accuracy: 0.6401 - val_loss: 0.9974 - learning_rate: 1.0000e-06
# Epoch 40/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7129 - loss: 0.6895 - val_accuracy: 0.6380 - val_loss: 0.9983 - learning_rate: 1.0000e-06
# Epoch 41/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7127 - loss: 0.6919 - val_accuracy: 0.6427 - val_loss: 0.9961 - learning_rate: 1.0000e-06
# Epoch 42/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7160 - loss: 0.7106 - val_accuracy: 0.6426 - val_loss: 0.9942 - learning_rate: 1.0000e-06
# Epoch 43/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7143 - loss: 0.7036 - val_accuracy: 0.6403 - val_loss: 0.9877 - learning_rate: 1.0000e-06
# Epoch 44/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7046 - loss: 0.7048 - val_accuracy: 0.6466 - val_loss: 0.9886 - learning_rate: 1.0000e-06
# Epoch 45/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 213ms/step - accuracy: 0.7122 - loss: 0.6982 - val_accuracy: 0.6459 - val_loss: 0.9891 - learning_rate: 1.0000e-06
# Epoch 46/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7106 - loss: 0.6966 - val_accuracy: 0.6403 - val_loss: 0.9902 - learning_rate: 1.0000e-06
# Epoch 47/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 218ms/step - accuracy: 0.7107 - loss: 0.6932 - val_accuracy: 0.6426 - val_loss: 0.9951 - learning_rate: 1.0000e-06
# Epoch 48/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.7111 - loss: 0.6885 - val_accuracy: 0.6424 - val_loss: 0.9916 - learning_rate: 1.0000e-06
# Epoch 49/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 38s 212ms/step - accuracy: 0.7143 - loss: 0.6985 - val_accuracy: 0.6419 - val_loss: 0.9934 - learning_rate: 1.0000e-06
# Epoch 50/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.7126 - loss: 0.7049 - val_accuracy: 0.6464 - val_loss: 0.9858 - learning_rate: 1.0000e-06
# Epoch 51/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - accuracy: 0.7092 - loss: 0.6952 - val_accuracy: 0.6407 - val_loss: 1.0062 - learning_rate: 1.0000e-06
# Epoch 52/100
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - accuracy: 0.7085 - loss: 0.7014 - val_accuracy: 0.6427 - val_loss: 0.9932 - learning_rate: 1.0000e-06

# %% [markdown]
# #Model Evaluation

# %%
# Evaluating on test set
test_loss,test_acc=model.evaluate(test_generator)
print("Test Loss:",test_loss)
print("Test Accuracy:",test_acc)

#Evaluating SGD model on test set
test_loss_SGD,test_acc_SGD=model_SGD.evaluate(test_generator)
print("SGD Test Loss:",test_loss_SGD)
print("SGD Test Accuracy:",test_acc_SGD)

# evaluating Adagrad model on test set
test_loss_Adagrad,test_acc_Adagrad=model_Adagrad.evaluate(test_generator)
print("Adagrad Test Loss:",test_loss_Adagrad)
print("Adagrad Test Accuracy:",test_acc_Adagrad)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 27s 480ms/step - accuracy: 0.6306 - loss: 1.0326
# Test Loss: 0.9727675914764404
# Test Accuracy: 0.6551964282989502
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step - accuracy: 0.6337 - loss: 1.0369
# SGD Test Loss: 0.9753552675247192
# SGD Test Accuracy: 0.6578434109687805
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - accuracy: 0.6255 - loss: 1.0456
# Adagrad Test Loss: 0.9798542261123657
# Adagrad Test Accuracy: 0.6519922018051147

# %%
# Predictions and metrics
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes, target_names=train_generator.class_indices.keys()))

#Predicting and metrics for SGD model
y_pred_SGD = model_SGD.predict(test_generator)
y_pred_classes_SGD = np.argmax(y_pred_SGD, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes_SGD, target_names=train_generator.class_indices.keys()))

#Predicting and metrics for Adagrad model
y_pred_Adagrad = model_Adagrad.predict(test_generator)
y_pred_classes_Adagrad = np.argmax(y_pred_Adagrad, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes_Adagrad, target_names=train_generator.class_indices.keys()))
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step
#               precision    recall  f1-score   support
#
#        angry       0.55      0.63      0.59       958
#      disgust       0.56      0.63      0.60       111
#         fear       0.51      0.43      0.47      1024
#        happy       0.90      0.82      0.86      1774
#      neutral       0.57      0.70      0.63      1233
#          sad       0.57      0.46      0.51      1247
#     surprise       0.72      0.83      0.77       831
#
#     accuracy                           0.66      7178
#    macro avg       0.63      0.64      0.63      7178
# weighted avg       0.66      0.66      0.65      7178
#
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 115ms/step
#               precision    recall  f1-score   support
#
#        angry       0.55      0.64      0.59       958
#      disgust       0.57      0.61      0.59       111
#         fear       0.51      0.43      0.46      1024
#        happy       0.91      0.82      0.86      1774
#      neutral       0.57      0.71      0.63      1233
#          sad       0.58      0.46      0.52      1247
#     surprise       0.73      0.83      0.78       831
#
#     accuracy                           0.66      7178
#    macro avg       0.63      0.64      0.63      7178
# weighted avg       0.66      0.66      0.66      7178
#
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step
#               precision    recall  f1-score   support
#
#        angry       0.55      0.63      0.59       958
#      disgust       0.55      0.60      0.58       111
#         fear       0.55      0.39      0.45      1024
#        happy       0.89      0.83      0.86      1774
#      neutral       0.54      0.74      0.63      1233
#          sad       0.57      0.44      0.50      1247
#     surprise       0.72      0.81      0.77       831
#
#     accuracy                           0.65      7178
#    macro avg       0.63      0.63      0.62      7178
# weighted avg       0.66      0.65      0.65      7178

# %%
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Plot training & validation accuracy and loss values for Adam optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')
plt.show()


# Plot training & validation accuracy and loss values for SGD optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_SGD.history['accuracy'], label='Train Acc')
plt.plot(history_SGD.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('SGD Optimizer - Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history_SGD.history['loss'], label='Train Loss')
plt.plot(history_SGD.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('SGD Optimizer - Loss')
plt.show()

# Plot training & validation accuracy and loss values for Adagrad optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_Adagrad.history['accuracy'], label='Train Acc')
plt.plot(history_Adagrad.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Adagrad Optimizer - Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history_Adagrad.history['loss'], label='Train Loss')
plt.plot(history_Adagrad.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Adagrad Optimizer - Loss')
plt.show()

# %% [markdown]
# # Predictions Visualization

# %%
# Visualizing correct & wrong predictions

# File paths from test generator
filenames = test_generator.filenames
n_samples = len(filenames)
n_display = 20  # Number of images to show (mix of correct and wrong)

# True labels and predictions
y_true = test_generator.classes
y_pred = np.argmax(model.predict(test_generator), axis=1)

# Correct and incorrect indices
correct_idx = np.where(y_true == y_pred)[0]
incorrect_idx = np.where(y_true != y_pred)[0]

# Shuffling & selecting some from each
np.random.shuffle(correct_idx)
np.random.shuffle(incorrect_idx)

selected_correct = correct_idx[:n_display // 2]
selected_incorrect = incorrect_idx[:min(len(incorrect_idx), n_display // 2)]

selected_idx = np.concatenate([selected_correct, selected_incorrect])
np.random.shuffle(selected_idx)

# Class names
class_names = list(train_generator.class_indices.keys())

plt.figure(figsize=(15, 3 * (n_display // 5 + 1)))
for i, idx in enumerate(selected_idx[:n_display]):
    # Load image
    img_path = os.path.join(test_path, filenames[idx])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE)  # Ensure same size

    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]
    correct = y_true[idx] == y_pred[idx]

    # Title color: green for correct, red for wrong
    color = 'green' if correct else 'red'
    title = f"True: {true_label}\nPred: {pred_label}"

    plt.subplot(n_display // 5 + 1, 5, i + 1)
    plt.imshow(img)
    plt.title(title, color=color, fontsize=10)
    plt.axis('off')

plt.suptitle("Correct (Green) vs Incorrect (Red) Predictions on Test Set", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step

# %%
# Save the trained model Adam_optimizer
model.save('emotion_detection_model_Adam_optimizer.keras')
print("Model saved to emotion_detection_model_Adam_optimizer.keras")

# Save the trained model SGD_optimizer
model_SGD.save('emotion_detection_model_SGD_optimizer.keras')
print("Model saved to emotion_detection_model_SGD_optimizer.keras")

# Save the trained model Adagrad_optimizer
model_Adagrad.save('emotion_detection_model_Adagrad_optimizer.keras')
print("Model saved to emotion_detection_model_Adagrad_optimizer.keras")
# Out:
# Model saved to emotion_detection_model_Adam_optimizer.keras
# Model saved to emotion_detection_model_SGD_optimizer.keras
# Model saved to emotion_detection_model_Adagrad_optimizer.keras

# %%
# from tensorflow.keras.models import load_model

# model = load_model('emotion_detection_model_Adam_optimizer.keras')
# print("Model loaded from emotion_detection_model_Adam_optimizer.keras")

# model = load_model('emotion_detection_model_SGD_optimizer.keras')
# print("Model loaded from emotion_detection_model_SGD_optimizer.keras")

# model = load_model('emotion_detection_model_Adagrad_optimizer.keras')
# print("Model loaded from emotion_detection_model_Adagrad_optimizer.keras")

# %%
from google.colab import drive
drive.mount('/content/drive')
