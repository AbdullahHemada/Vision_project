# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahHemada/Vision_project/blob/main/_final_fer_2013_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This cell loads the `fer2013` dataset from KaggleHub and stores its path.

# %%
import kagglehub
path = kagglehub.dataset_download("msambare/fer2013")
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.

# %%
# import libraries
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization #for CNN model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix  #for training report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential   #for training model
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import random
import cv2
import os
from keras.regularizers import l2
from keras.layers import Activation
from keras.models import Model
from keras.layers import Input
from keras import layers
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import AveragePooling2D
from keras.layers import Flatten
from keras.layers import MaxPool2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# #Visualizing Data

# %% [markdown]
# This cell defines the file paths for the training and testing datasets based on the previously loaded KaggleHub path.

# %%
train_path = os.path.join(path, 'train')
test_path = os.path.join(path, 'test')

# %%
classes=os.listdir(train_path)
print("Existing Classes :",classes)

plt.figure(figsize=(15,5))
for index,emotion in enumerate(classes):
  emotion_path=os.path.join(train_path,emotion)
  rand_image=random.choice(os.listdir(emotion_path))
  image_path=os.path.join(emotion_path,rand_image)
  image=cv2.imread(image_path)
  img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  plt.subplot(1, len(classes), index+1)
  plt.imshow(img)
  plt.title(emotion)
  plt.axis("off")

plt.tight_layout()
plt.show()


# Function to count images per class in a given path
def count_images_per_class(base_path, classes):
    counts = {}
    for emotion in classes:
        emotion_dir = os.path.join(base_path, emotion)
        if os.path.exists(emotion_dir):
            counts[emotion] = len(os.listdir(emotion_dir))
        else:
            counts[emotion] = 0
    return counts

# Count images for training set
train_counts = count_images_per_class(train_path, classes)
train_df = pd.DataFrame.from_dict(train_counts, orient='index', columns=['Train Count'])

# Count images for testing set
test_counts = count_images_per_class(test_path, classes)
test_df = pd.DataFrame.from_dict(test_counts, orient='index', columns=['Test Count'])

# Display the summary in a formatted way
print("train_counts: \n")
display(train_df)
print("\ntest_counts:")
display(test_df)

print("total train image :",train_df['Train Count'].sum())
print("total test image :",test_df['Test Count'].sum())
# Out:
# Existing Classes : ['surprise', 'fear', 'angry', 'neutral', 'sad', 'disgust', 'happy']
# train_counts:
#           Train Count
# surprise         3171
# fear             4097
# angry            3995
# neutral          4965
# sad              4830
# disgust           436
# happy            7215
# test_counts:
#           Test Count
# surprise         831
# fear            1024
# angry            958
# neutral         1233
# sad             1247
# disgust          111
# happy           1774
# total train image : 28709
# total test image : 7178

# %% [markdown]
# # Images shape

# %%
print(f"Image dimensions: {img.shape}") # Output from the previously executed cell
# Out:
# Image dimensions: (48, 48, 3)

# %% [markdown]
# ### Dataset Class Distribution Visualization

# %%
# Visualize class distribution for training set
plt.figure(figsize=(12, 6))
sns.barplot(x=train_df.index, y='Train Count', data=train_df, palette='viridis', hue=train_df.index, legend=False)
plt.title('Training Data: Number of Images per Emotion Class')
plt.xlabel('Emotion')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Visualize class distribution for testing set
plt.figure(figsize=(12, 6))
sns.barplot(x=test_df.index, y='Test Count', data=test_df, palette='plasma', hue=test_df.index, legend=False)
plt.title('Test Data: Number of Images per Emotion Class')
plt.xlabel('Emotion')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Data Augmentation

# %%
# Image parameters
IMG_SIZE = (96, 96)
BATCH_SIZE = 224
EPOCHS = 100
NUM_CLASSES = 7

# %%
# Data generators with augmentation for trainingt
train_datagen=ImageDataGenerator(
    rescale=1./255,       #Normalization
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2  # 20% for validation
)

# %%
# Data generators with Normalizing for testing
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Loading training data
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 22968 images belonging to 7 classes.

# %%
# Loading validation data
val_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=IMG_SIZE,
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 5741 images belonging to 7 classes.

# %%
# Loading test data
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=IMG_SIZE,
    color_mode='rgb', # Changed from 'grayscale' to 'rgb'
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
# Take one image
images, labels = next(train_generator)
img = images[0]

# Plot original + augmented versions
plt.figure(figsize=(12, 6))

plt.subplot(2, 5, 1)
plt.imshow(img)
plt.title("Original")
plt.axis('off')

# Show 8 augmented versions
for i in range(8):
    augmented_img = train_datagen.random_transform(img)
    plt.subplot(2, 5, i + 2)
    plt.imshow(augmented_img)
    plt.title(f"Aug {i+1}")
    plt.axis('off')

plt.suptitle("Original Image vs Augmented Versions", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Building the CNN Model

# %%
def build_resnet50_fer(num_classes=7):
    inputs = Input(shape=(IMG_SIZE[0],IMG_SIZE[1], 3))
    x = preprocess_input(inputs)

    base_model = ResNet50(
        include_top=False,
        weights='imagenet',
        input_tensor=x
    )
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)

    return model

# %% [markdown]
# #Optimizer

# %%
model_Adam = build_resnet50_fer()
model_Adam.compile(optimizer=tf.keras.optimizers.Adam(learning_rate= 0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_SGD = build_resnet50_fer()
model_SGD.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate= 0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_Adagrad = build_resnet50_fer()
model_Adagrad.compile(
    optimizer=tf.keras.optimizers.Adagrad(learning_rate= 0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_Adam.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_9          │ (None, 96, 96)    │          0 │ input_layer_3[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_10         │ (None, 96, 96)    │          0 │ input_layer_3[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_11         │ (None, 96, 96)    │          0 │ input_layer_3[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_3 (Stack)     │ (None, 96, 96, 3) │          0 │ get_item_9[0][0], │
# │                     │                   │            │ get_item_10[0][0… │
# │                     │                   │            │ get_item_11[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 96, 96, 3) │          0 │ stack_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 102, 102,  │          0 │ add_3[0][0]       │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 48, 48,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 48, 48,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 48, 48,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 50, 50,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 24, 24,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 24, 24,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 24, 24,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 24, 24,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 24, 24,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 24, 24,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 24, 24,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 24, 24,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 24, 24,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 24, 24,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 24, 24,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 24, 24,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 24, 24,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 24, 24,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 24, 24,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 24, 24,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 24, 24,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 24, 24,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 24, 24,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 24, 24,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 24, 24,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 24, 24,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 24, 24,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 24, 24,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 24, 24,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 24, 24,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 24, 24,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 24, 24,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 24, 24,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 24, 24,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 24, 24,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 24, 24,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 24, 24,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 12, 12,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 12, 12,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 12, 12,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 12, 12,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 12, 12,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 12, 12,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 12, 12,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 12, 12,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 12, 12,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 12, 12,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 12, 12,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 12, 12,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 12, 12,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 12, 12,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 12, 12,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 12, 12,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 12, 12,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 12, 12,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 12, 12,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 12, 12,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 12, 12,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 12, 12,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 12, 12,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 12, 12,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 12, 12,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 12, 12,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 12, 12,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 12, 12,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 12, 12,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 12, 12,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 12, 12,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 12, 12,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 12, 12,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 12, 12,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 12, 12,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 12, 12,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 12, 12,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 12, 12,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 12, 12,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 12, 12,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 12, 12,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 12, 12,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 6, 6, 256) │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 6, 6,      │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 6, 6,      │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 6, 6,      │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 6, 6,      │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 6, 6, 256) │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 6, 6,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 6, 6,      │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 6, 6, 256) │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 6, 6,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 6, 6,      │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 6, 6, 256) │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 6, 6,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 6, 6,      │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 6, 6, 256) │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 6, 6,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 6, 6,      │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 6, 6, 256) │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 6, 6, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 6, 6, 256) │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 6, 6, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 6, 6, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 6, 6,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 6, 6,      │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 6, 6,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 6, 6,      │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 3, 3, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 3, 3, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 3, 3, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 3, 3, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 3, 3,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 3, 3,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 3, 3,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 3, 3,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 3, 3,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 3, 3,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 3, 3, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 3, 3, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 3, 3, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 3, 3, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 3, 3,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 3, 3,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 3, 3,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 3, 3,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 3, 3, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 3, 3, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 3, 3, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 3, 3, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 3, 3, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 3, 3,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 3, 3,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 3, 3,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 3, 3,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 512)       │  1,049,088 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 7)         │      3,591 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,640,391 (94.00 MB)
#  Trainable params: 1,052,679 (4.02 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
#early stop to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)

# %%
# We use class weights to address class imbalance since some classes have fewer samples.

# 1. Get the class indices and counts from the training generator
class_lable=train_generator.classes
num_classes=train_generator.num_classes

# 2. Compute class weights
class_weights_array=class_weight.compute_class_weight(class_weight='balanced',classes=np.unique(class_lable),y=class_lable)

class_weights = dict(enumerate(class_weights_array))
print("Calculated Class Weights:", class_weights)
# Out:
# Calculated Class Weights: {0: np.float64(1.0266404434114071), 1: np.float64(9.401555464592715), 2: np.float64(1.0009587727708533), 3: np.float64(0.5684585684585685), 4: np.float64(0.826068191627104), 5: np.float64(0.8491570541259982), 6: np.float64(1.2933160650937552)}

# %% [markdown]
# #Model Training

# %%
history=model_Adam.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 107s 936ms/step - accuracy: 0.1352 - loss: 2.0635 - val_accuracy: 0.1237 - val_loss: 1.9299 - learning_rate: 0.0010
# Epoch 2/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 837ms/step - accuracy: 0.1241 - loss: 1.9516 - val_accuracy: 0.1812 - val_loss: 1.9338 - learning_rate: 0.0010
# Epoch 3/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 85s 828ms/step - accuracy: 0.1371 - loss: 1.9440 - val_accuracy: 0.1094 - val_loss: 1.9621 - learning_rate: 0.0010
# Epoch 4/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 837ms/step - accuracy: 0.1545 - loss: 1.9220 - val_accuracy: 0.1724 - val_loss: 1.9437 - learning_rate: 0.0010
# Epoch 5/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 832ms/step - accuracy: 0.1608 - loss: 1.9494 - val_accuracy: 0.1730 - val_loss: 1.9399 - learning_rate: 0.0010
# Epoch 6/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 85s 828ms/step - accuracy: 0.1541 - loss: 1.9477 - val_accuracy: 0.1587 - val_loss: 1.9357 - learning_rate: 0.0010
# Epoch 7/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 832ms/step - accuracy: 0.1550 - loss: 1.9424 - val_accuracy: 0.1921 - val_loss: 1.9295 - learning_rate: 0.0010
# Epoch 8/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 843ms/step - accuracy: 0.1743 - loss: 1.9381 - val_accuracy: 0.2407 - val_loss: 1.9253 - learning_rate: 0.0010
# Epoch 9/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.1900 - loss: 1.9151 - val_accuracy: 0.1986 - val_loss: 1.9259 - learning_rate: 0.0010
# Epoch 10/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 834ms/step - accuracy: 0.1785 - loss: 1.9398 - val_accuracy: 0.1841 - val_loss: 1.9247 - learning_rate: 0.0010
# Epoch 11/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 836ms/step - accuracy: 0.1908 - loss: 1.9113 - val_accuracy: 0.2026 - val_loss: 1.9281 - learning_rate: 0.0010
# Epoch 12/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 844ms/step - accuracy: 0.2021 - loss: 1.9462 - val_accuracy: 0.2369 - val_loss: 1.9216 - learning_rate: 0.0010
# Epoch 13/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.2135 - loss: 1.9451 - val_accuracy: 0.2540 - val_loss: 1.9119 - learning_rate: 0.0010
# Epoch 14/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 834ms/step - accuracy: 0.2113 - loss: 1.8987 - val_accuracy: 0.2510 - val_loss: 1.9102 - learning_rate: 0.0010
# Epoch 15/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.2036 - loss: 1.9549 - val_accuracy: 0.1843 - val_loss: 1.9236 - learning_rate: 0.0010
# Epoch 16/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 853ms/step - accuracy: 0.2047 - loss: 1.9209 - val_accuracy: 0.2223 - val_loss: 1.9148 - learning_rate: 0.0010
# Epoch 17/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 853ms/step - accuracy: 0.2133 - loss: 1.9306 - val_accuracy: 0.2162 - val_loss: 1.9052 - learning_rate: 0.0010
# Epoch 18/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 850ms/step - accuracy: 0.2119 - loss: 1.9281 - val_accuracy: 0.2153 - val_loss: 1.9056 - learning_rate: 0.0010
# Epoch 19/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 856ms/step - accuracy: 0.2099 - loss: 1.9010 - val_accuracy: 0.1667 - val_loss: 1.9207 - learning_rate: 0.0010
# Epoch 20/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 90s 877ms/step - accuracy: 0.2023 - loss: 1.9132 - val_accuracy: 0.2566 - val_loss: 1.9023 - learning_rate: 0.0010
# Epoch 21/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 839ms/step - accuracy: 0.2193 - loss: 1.8894 - val_accuracy: 0.2432 - val_loss: 1.9125 - learning_rate: 0.0010
# Epoch 22/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 840ms/step - accuracy: 0.2146 - loss: 1.9123 - val_accuracy: 0.1630 - val_loss: 1.9232 - learning_rate: 0.0010
# Epoch 23/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 850ms/step - accuracy: 0.2183 - loss: 1.9195 - val_accuracy: 0.2494 - val_loss: 1.8986 - learning_rate: 0.0010
# Epoch 24/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 849ms/step - accuracy: 0.2262 - loss: 1.8930 - val_accuracy: 0.2611 - val_loss: 1.9062 - learning_rate: 0.0010
# Epoch 25/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 856ms/step - accuracy: 0.2331 - loss: 1.9135 - val_accuracy: 0.2153 - val_loss: 1.9172 - learning_rate: 0.0010
# Epoch 26/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 849ms/step - accuracy: 0.2119 - loss: 1.8859 - val_accuracy: 0.2507 - val_loss: 1.9065 - learning_rate: 0.0010
# Epoch 27/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 843ms/step - accuracy: 0.2198 - loss: 1.9188 - val_accuracy: 0.2473 - val_loss: 1.9043 - learning_rate: 0.0010
# Epoch 28/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 845ms/step - accuracy: 0.2289 - loss: 1.8942 - val_accuracy: 0.2649 - val_loss: 1.8942 - learning_rate: 0.0010
# Epoch 29/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 849ms/step - accuracy: 0.2278 - loss: 1.9146 - val_accuracy: 0.2541 - val_loss: 1.9050 - learning_rate: 0.0010
# Epoch 30/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 855ms/step - accuracy: 0.2324 - loss: 1.8927 - val_accuracy: 0.2202 - val_loss: 1.8977 - learning_rate: 0.0010
# Epoch 31/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 846ms/step - accuracy: 0.2204 - loss: 1.9010 - val_accuracy: 0.2447 - val_loss: 1.8962 - learning_rate: 0.0010
# Epoch 32/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 844ms/step - accuracy: 0.2213 - loss: 1.9177 - val_accuracy: 0.2392 - val_loss: 1.8980 - learning_rate: 0.0010
# Epoch 33/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 843ms/step - accuracy: 0.2016 - loss: 1.9077 - val_accuracy: 0.2014 - val_loss: 1.9022 - learning_rate: 0.0010
# Epoch 34/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 842ms/step - accuracy: 0.2297 - loss: 1.9073 - val_accuracy: 0.2608 - val_loss: 1.8928 - learning_rate: 0.0010
# Epoch 35/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 836ms/step - accuracy: 0.2205 - loss: 1.8972 - val_accuracy: 0.2743 - val_loss: 1.8886 - learning_rate: 0.0010
# Epoch 36/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 849ms/step - accuracy: 0.2120 - loss: 1.8886 - val_accuracy: 0.2735 - val_loss: 1.8872 - learning_rate: 0.0010
# Epoch 37/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.2184 - loss: 1.9079 - val_accuracy: 0.2700 - val_loss: 1.8894 - learning_rate: 0.0010
# Epoch 38/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.2227 - loss: 1.9058 - val_accuracy: 0.1585 - val_loss: 1.9070 - learning_rate: 0.0010
# Epoch 39/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 836ms/step - accuracy: 0.2084 - loss: 1.8993 - val_accuracy: 0.2249 - val_loss: 1.9044 - learning_rate: 0.0010
# Epoch 40/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 840ms/step - accuracy: 0.2030 - loss: 1.8934 - val_accuracy: 0.2165 - val_loss: 1.9055 - learning_rate: 0.0010
# Epoch 41/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 855ms/step - accuracy: 0.2080 - loss: 1.8973 - val_accuracy: 0.2608 - val_loss: 1.8983 - learning_rate: 0.0010
# Epoch 42/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 851ms/step - accuracy: 0.2080 - loss: 1.8935 - val_accuracy: 0.2729 - val_loss: 1.8914 - learning_rate: 0.0010
# Epoch 43/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 841ms/step - accuracy: 0.2043 - loss: 1.9116 - val_accuracy: 0.2613 - val_loss: 1.8941 - learning_rate: 0.0010
# Epoch 44/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 837ms/step - accuracy: 0.2082 - loss: 1.9076 - val_accuracy: 0.2615 - val_loss: 1.8828 - learning_rate: 0.0010
# Epoch 45/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 840ms/step - accuracy: 0.2218 - loss: 1.8992 - val_accuracy: 0.2658 - val_loss: 1.8838 - learning_rate: 0.0010
# Epoch 46/100
#  73/103 ━━━━━━━━━━━━━━━━━━━━ 19s 666ms/step - accuracy: 0.2096 - loss: 1.8913
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2846767013.py in <cell line: 0>()
# ----> 1 history=model_Adam.fit(
#       2     train_generator,
#       3     validation_data=val_generator,
#       4     epochs=EPOCHS,
#       5     callbacks=[early_stop, reduce_lr],
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#fit model with SGD optimizer
history_SGD=model_SGD.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.1474 - loss: 2.1502 - val_accuracy: 0.1629 - val_loss: 1.9432 - learning_rate: 0.0010
# Epoch 2/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 855ms/step - accuracy: 0.1440 - loss: 2.0718 - val_accuracy: 0.0341 - val_loss: 1.9546 - learning_rate: 0.0010
# Epoch 3/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 837ms/step - accuracy: 0.1470 - loss: 1.9813 - val_accuracy: 0.0488 - val_loss: 1.9547 - learning_rate: 0.0010
# Epoch 4/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 841ms/step - accuracy: 0.1364 - loss: 2.0152 - val_accuracy: 0.1643 - val_loss: 1.9289 - learning_rate: 0.0010
# Epoch 5/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 850ms/step - accuracy: 0.1421 - loss: 2.0026 - val_accuracy: 0.1697 - val_loss: 1.9377 - learning_rate: 0.0010
# Epoch 6/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 853ms/step - accuracy: 0.1474 - loss: 1.9584 - val_accuracy: 0.1000 - val_loss: 1.9541 - learning_rate: 0.0010
# Epoch 7/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.1451 - loss: 1.9525 - val_accuracy: 0.0230 - val_loss: 1.9591 - learning_rate: 0.0010
# Epoch 8/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 842ms/step - accuracy: 0.1382 - loss: 1.9542 - val_accuracy: 0.1623 - val_loss: 1.9387 - learning_rate: 0.0010
# Epoch 9/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 90s 879ms/step - accuracy: 0.1386 - loss: 1.9744 - val_accuracy: 0.1759 - val_loss: 1.9330 - learning_rate: 0.0010
# Epoch 10/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 89s 860ms/step - accuracy: 0.1443 - loss: 1.9666 - val_accuracy: 0.1869 - val_loss: 1.9262 - learning_rate: 0.0010
# Epoch 11/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 834ms/step - accuracy: 0.1506 - loss: 1.9644 - val_accuracy: 0.1831 - val_loss: 1.9375 - learning_rate: 0.0010
# Epoch 12/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 852ms/step - accuracy: 0.1599 - loss: 1.9259 - val_accuracy: 0.0625 - val_loss: 1.9511 - learning_rate: 0.0010
# Epoch 13/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 845ms/step - accuracy: 0.1284 - loss: 1.9613 - val_accuracy: 0.1832 - val_loss: 1.9205 - learning_rate: 0.0010
# Epoch 14/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.1698 - loss: 1.9298 - val_accuracy: 0.1089 - val_loss: 1.9467 - learning_rate: 0.0010
# Epoch 15/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 842ms/step - accuracy: 0.1358 - loss: 1.9481 - val_accuracy: 0.1747 - val_loss: 1.9412 - learning_rate: 0.0010
# Epoch 16/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 841ms/step - accuracy: 0.1310 - loss: 1.9635 - val_accuracy: 0.2068 - val_loss: 1.9369 - learning_rate: 0.0010
# Epoch 17/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 846ms/step - accuracy: 0.1567 - loss: 1.9544 - val_accuracy: 0.2184 - val_loss: 1.9379 - learning_rate: 0.0010
# Epoch 18/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.1832 - loss: 1.8961 - val_accuracy: 0.0383 - val_loss: 1.9577 - learning_rate: 0.0010
# Epoch 19/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.1413 - loss: 1.9287 - val_accuracy: 0.1686 - val_loss: 1.9407 - learning_rate: 0.0010
# Epoch 20/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 834ms/step - accuracy: 0.1716 - loss: 1.9255 - val_accuracy: 0.0509 - val_loss: 1.9513 - learning_rate: 0.0010
# Epoch 21/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 835ms/step - accuracy: 0.1338 - loss: 1.9434 - val_accuracy: 0.1446 - val_loss: 1.9431 - learning_rate: 0.0010
# Epoch 22/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 85s 831ms/step - accuracy: 0.1471 - loss: 1.9527 - val_accuracy: 0.2146 - val_loss: 1.9367 - learning_rate: 0.0010
# Epoch 23/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 840ms/step - accuracy: 0.1771 - loss: 1.9340 - val_accuracy: 0.1862 - val_loss: 1.9362 - learning_rate: 0.0010
# Epoch 24/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 837ms/step - accuracy: 0.1722 - loss: 1.9370 - val_accuracy: 0.2000 - val_loss: 1.9364 - learning_rate: 2.0000e-04
# Epoch 25/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.1792 - loss: 1.9302 - val_accuracy: 0.2024 - val_loss: 1.9383 - learning_rate: 2.0000e-04
# Epoch 26/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 859ms/step - accuracy: 0.1744 - loss: 1.9304 - val_accuracy: 0.2000 - val_loss: 1.9387 - learning_rate: 2.0000e-04
# Epoch 27/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 844ms/step - accuracy: 0.1662 - loss: 1.9594 - val_accuracy: 0.2019 - val_loss: 1.9371 - learning_rate: 2.0000e-04
# Epoch 28/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 852ms/step - accuracy: 0.1651 - loss: 1.9589 - val_accuracy: 0.2043 - val_loss: 1.9376 - learning_rate: 2.0000e-04
# Epoch 29/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 852ms/step - accuracy: 0.1804 - loss: 1.9393 - val_accuracy: 0.2104 - val_loss: 1.9375 - learning_rate: 2.0000e-04
# Epoch 30/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 88s 851ms/step - accuracy: 0.1723 - loss: 1.9492 - val_accuracy: 0.2118 - val_loss: 1.9371 - learning_rate: 2.0000e-04
# Epoch 31/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.1666 - loss: 1.9482 - val_accuracy: 0.2205 - val_loss: 1.9363 - learning_rate: 2.0000e-04
# Epoch 32/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 86s 839ms/step - accuracy: 0.1808 - loss: 1.9436 - val_accuracy: 0.2268 - val_loss: 1.9353 - learning_rate: 2.0000e-04
# Epoch 33/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 87s 841ms/step - accuracy: 0.1859 - loss: 1.9375 - val_accuracy: 0.2116 - val_loss: 1.9364 - learning_rate: 2.0000e-04

# %%
#fit model with Adagrad optimizer
history_Adagrad=model_Adagrad.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)

# %% [markdown]
# #Model Evaluation

# %%
# Evaluating on test set
test_loss,test_acc=model_Adam.evaluate(test_generator)
print("Test Loss:",test_loss)
print("Test Accuracy:",test_acc)

#Evaluating SGD model on test set
test_loss_SGD,test_acc_SGD=model_SGD.evaluate(test_generator)
print("SGD Test Loss:",test_loss_SGD)
print("SGD Test Accuracy:",test_acc_SGD)

# evaluating Adagrad model on test set
test_loss_Adagrad,test_acc_Adagrad=model_Adagrad.evaluate(test_generator)
print("Adagrad Test Loss:",test_loss_Adagrad)
print("Adagrad Test Accuracy:",test_acc_Adagrad)

# %%
# Predictions and metrics
y_pred = model_Adam.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes, target_names=train_generator.class_indices.keys()))

#Predicting and metrics for SGD model
y_pred_SGD = model_SGD.predict(test_generator)
y_pred_classes_SGD = np.argmax(y_pred_SGD, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes_SGD, target_names=train_generator.class_indices.keys()))

#Predicting and metrics for Adagrad model
y_pred_Adagrad = model_Adagrad.predict(test_generator)
y_pred_classes_Adagrad = np.argmax(y_pred_Adagrad, axis=1)
y_true = test_generator.classes
print(classification_report(y_true, y_pred_classes_Adagrad, target_names=train_generator.class_indices.keys()))

# %%
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Plot training & validation accuracy and loss values for Adam optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')
plt.show()


# Plot training & validation accuracy and loss values for SGD optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_SGD.history['accuracy'], label='Train Acc')
plt.plot(history_SGD.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('SGD Optimizer - Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history_SGD.history['loss'], label='Train Loss')
plt.plot(history_SGD.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('SGD Optimizer - Loss')
plt.show()

# Plot training & validation accuracy and loss values for Adagrad optimizer
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_Adagrad.history['accuracy'], label='Train Acc')
plt.plot(history_Adagrad.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Adagrad Optimizer - Accuracy')
plt.subplot(1, 2, 2)
plt.plot(history_Adagrad.history['loss'], label='Train Loss')
plt.plot(history_Adagrad.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Adagrad Optimizer - Loss')
plt.show()

# %% [markdown]
# # Predictions Visualization

# %%
# Visualizing correct & wrong predictions

# File paths from test generator
filenames = test_generator.filenames
n_samples = len(filenames)
n_display = 20  # Number of images to show (mix of correct and wrong)

# True labels and predictions
y_true = test_generator.classes
y_pred = np.argmax(model_Adam.predict(test_generator), axis=1)

# Correct and incorrect indices
correct_idx = np.where(y_true == y_pred)[0]
incorrect_idx = np.where(y_true != y_pred)[0]

# Shuffling & selecting some from each
np.random.shuffle(correct_idx)
np.random.shuffle(incorrect_idx)

selected_correct = correct_idx[:n_display // 2]
selected_incorrect = incorrect_idx[:min(len(incorrect_idx), n_display // 2)]

selected_idx = np.concatenate([selected_correct, selected_incorrect])
np.random.shuffle(selected_idx)

# Class names
class_names = list(train_generator.class_indices.keys())

plt.figure(figsize=(15, 3 * (n_display // 5 + 1)))
for i, idx in enumerate(selected_idx[:n_display]):
    # Load image
    img_path = os.path.join(test_path, filenames[idx])
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE)  # Ensure same size

    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]
    correct = y_true[idx] == y_pred[idx]

    # Title color: green for correct, red for wrong
    color = 'green' if correct else 'red'
    title = f"True: {true_label}\nPred: {pred_label}"

    plt.subplot(n_display // 5 + 1, 5, i + 1)
    plt.imshow(img)
    plt.title(title, color=color, fontsize=10)
    plt.axis('off')

plt.suptitle("Correct (Green) vs Incorrect (Red) Predictions on Test Set", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Save the trained model Adam_optimizer
model_Adam.save('Emotion_Recognition_model_Adam_optimizer.keras')
print("Model saved to Emotion Recognition_model_Adam_optimizer.keras")

# Save the trained model SGD_optimizer
model_SGD.save('Emotion_Recognition_model_SGD_optimizer.keras')
print("Model saved to Emotion Recognition_model_SGD_optimizer.keras")

# Save the trained model Adagrad_optimizer
model_Adagrad.save('Emotion_Recognition_model_Adagrad_optimizer.keras')
print("Model saved to Emotion Recognition_model_Adagrad_optimizer.keras")
