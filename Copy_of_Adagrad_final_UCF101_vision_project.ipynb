# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahHemada/Vision_project/blob/main/Copy_of_Adagrad_final_UCF101_vision_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
pevogam_ucf101_path = kagglehub.dataset_download('pevogam/ucf101')

print('Data source import complete.')

# %% [markdown]
# # Import packages

# %%
import os
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import time


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam,SGD,Adagrad
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model

from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Input, TimeDistributed, LSTM, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
# Out:
# /usr/local/lib/python3.12/site-packages/jax/_src/cloud_tpu_init.py:93: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %% [markdown]
# # Import Label File

# %%
label_data = pd.read_csv("/kaggle/input/ucf101/UCF101TrainTestSplits-RecognitionTask/ucfTrainTestlist/classInd.txt", sep=' ', header=None)
label_data.columns=['index', 'labels']
# label_data = label_data.drop(['index'], axis=1)
label_data.head()
# Out:
#    index          labels
# 0      1  ApplyEyeMakeup
# 1      2   ApplyLipstick
# 2      3         Archery
# 3      4    BabyCrawling
# 4      5     BalanceBeam

# %%
# Total Number of video folders for classification
print(len(label_data))
print(label_data['index'],label_data['labels'])
# Out:
# 101
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 96      97
# 97      98
# 98      99
# 99     100
# 100    101
# Name: index, Length: 101, dtype: int64 0         ApplyEyeMakeup
# 1          ApplyLipstick
# 2                Archery
# 3           BabyCrawling
# 4            BalanceBeam
#              ...
# 96     VolleyballSpiking
# 97        WalkingWithDog
# 98           WallPushups
# 99        WritingOnBoard
# 100                 YoYo
# Name: labels, Length: 101, dtype: object

# %% [markdown]
# # Hyperparameter

# %%
# # Parameters
IMG_SIZE = (96, 96)
SEQUENCE_LENGTH = 16
BATCH_SIZE = 32
EPOCHS = 50
NUM_CLASSES = 101
SAMPLES_PER_CLASS = 50   # increase samples per class to reduce overfitting

# %% [markdown]
# # import and read train01 and test01

# %%
#read train01.txt file
UCF101_path='/kaggle/input/ucf101/UCF101/UCF-101'
train01_path='/kaggle/input/ucf101/UCF101TrainTestSplits-RecognitionTask/ucfTrainTestlist/trainlist01.txt'
test01_path='/kaggle/input/ucf101/UCF101TrainTestSplits-RecognitionTask/ucfTrainTestlist/testlist01.txt'

def load_train_list(train01_path):
    videos=[]
    labels=[]
    with open(train01_path,'r')as file:
        for line in file:
            video_path,label=line.strip().split()
            videos.append(video_path)
            labels.append(int(label)-1)

    return videos,labels

#read test01.txt file
def load_test_list(test01_path):
    videos=[]
    with open(test01_path,'r')as file:
        for line in file:
            video_path=line.strip()
            videos.append(video_path)

    return videos

# %% [markdown]
# # Data Preperation

# %% [markdown]
# # Get video fram size

# %%
# get video fram size
# folder = UCF101_path
# for root, dirs, files in os.walk(folder):
#     for file in files:
#         if file.endswith(".avi"):
#             video_path = os.path.join(root, file)
#             cap = cv2.VideoCapture(video_path)
#             w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#             h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#             print(f"{file}: {w}x{h}")
#             cap.release()

# %% [markdown]
# # ploting each category and its number

# %%
# ploting each category and its number
folder = UCF101_path
categories = [d for d in os.listdir(folder) if os.path.isdir(os.path.join(folder, d))]

# Count videos in each category
video_counts = {}
for category in categories:
    category_path = os.path.join(folder, category)
    videos = [f for f in os.listdir(category_path) if f.endswith(".avi")]
    video_counts[category] = len(videos)

# Sort categories by number of videos (descending)
sorted_counts = dict(sorted(video_counts.items(), key=lambda item: item[1], reverse=True))

# Plot bar chart
plt.figure(figsize=(30, 10))
plt.bar(sorted_counts.keys(), sorted_counts.values(), color='skyblue')
plt.xticks(rotation=90)
plt.ylabel("Number of Videos")
plt.title("Number of Videos per Category in UCF101")
plt.tight_layout()
plt.show()

# %% [markdown]
# # LOAD ALL FRAMES FOR TRAINING AND TESTING

# %%
#load train01.txt file
train_videos, train_labels = load_train_list(train01_path)
test_videos = load_test_list(test01_path)

# label_data: DataFrame containing index and class name
class_to_index = {cls: i for i, cls in enumerate(sorted(label_data['labels']))}
print(class_to_index)


train_full_path=[]
for video in train_videos:
    train_full_path.append(os.path.join(UCF101_path, video))


test_full_path=[]
for video in test_videos:
    test_full_path.append(os.path.join(UCF101_path, video))

# print(train_full_path)
# print(test_full_path)
# Out:
# {'ApplyEyeMakeup': 0, 'ApplyLipstick': 1, 'Archery': 2, 'BabyCrawling': 3, 'BalanceBeam': 4, 'BandMarching': 5, 'BaseballPitch': 6, 'Basketball': 7, 'BasketballDunk': 8, 'BenchPress': 9, 'Biking': 10, 'Billiards': 11, 'BlowDryHair': 12, 'BlowingCandles': 13, 'BodyWeightSquats': 14, 'Bowling': 15, 'BoxingPunchingBag': 16, 'BoxingSpeedBag': 17, 'BreastStroke': 18, 'BrushingTeeth': 19, 'CleanAndJerk': 20, 'CliffDiving': 21, 'CricketBowling': 22, 'CricketShot': 23, 'CuttingInKitchen': 24, 'Diving': 25, 'Drumming': 26, 'Fencing': 27, 'FieldHockeyPenalty': 28, 'FloorGymnastics': 29, 'FrisbeeCatch': 30, 'FrontCrawl': 31, 'GolfSwing': 32, 'Haircut': 33, 'HammerThrow': 34, 'Hammering': 35, 'HandstandPushups': 36, 'HandstandWalking': 37, 'HeadMassage': 38, 'HighJump': 39, 'HorseRace': 40, 'HorseRiding': 41, 'HulaHoop': 42, 'IceDancing': 43, 'JavelinThrow': 44, 'JugglingBalls': 45, 'JumpRope': 46, 'JumpingJack': 47, 'Kayaking': 48, 'Knitting': 49, 'LongJump': 50, 'Lunges': 51, 'MilitaryParade': 52, 'Mixing': 53, 'MoppingFloor': 54, 'Nunchucks': 55, 'ParallelBars': 56, 'PizzaTossing': 57, 'PlayingCello': 58, 'PlayingDaf': 59, 'PlayingDhol': 60, 'PlayingFlute': 61, 'PlayingGuitar': 62, 'PlayingPiano': 63, 'PlayingSitar': 64, 'PlayingTabla': 65, 'PlayingViolin': 66, 'PoleVault': 67, 'PommelHorse': 68, 'PullUps': 69, 'Punch': 70, 'PushUps': 71, 'Rafting': 72, 'RockClimbingIndoor': 73, 'RopeClimbing': 74, 'Rowing': 75, 'SalsaSpin': 76, 'ShavingBeard': 77, 'Shotput': 78, 'SkateBoarding': 79, 'Skiing': 80, 'Skijet': 81, 'SkyDiving': 82, 'SoccerJuggling': 83, 'SoccerPenalty': 84, 'StillRings': 85, 'SumoWrestling': 86, 'Surfing': 87, 'Swing': 88, 'TableTennisShot': 89, 'TaiChi': 90, 'TennisSwing': 91, 'ThrowDiscus': 92, 'TrampolineJumping': 93, 'Typing': 94, 'UnevenBars': 95, 'VolleyballSpiking': 96, 'WalkingWithDog': 97, 'WallPushups': 98, 'WritingOnBoard': 99, 'YoYo': 100}

# %% [markdown]
# # Function for Feature Extraction

# %%
def feature_extraction(video_path, augment=False):
    width, height = IMG_SIZE
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)

    frame_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    if frame_count <= 0:
        return [np.zeros((height, width, 3), dtype=np.float32) for _ in range(SEQUENCE_LENGTH)]

    # random start for training only
    if frame_count > SEQUENCE_LENGTH:
        start = random.randint(0, frame_count - SEQUENCE_LENGTH)
        indices = list(range(start, start + SEQUENCE_LENGTH))
    else:
        indices = np.linspace(0, frame_count - 1, SEQUENCE_LENGTH, dtype=int)

    for idx in indices:
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = video_reader.read()

        if not ret:
            frame = np.zeros((height, width, 3), np.float32)
        else:
            frame = cv2.resize(frame, (width, height)).astype("float32")

        # -------------------------
        # AUGMENT ONLY IF TRAINING
        # -------------------------
        if augment:
            # flip
            if random.random() < 0.5:
                frame = cv2.flip(frame, 1)

            # brightness
            if random.random() < 0.3:
                factor = 0.8 + random.random() * 0.4
                frame = np.clip(frame * factor, 0, 255)

            # jitter
            if random.random() < 0.3:
                shift = random.randint(-15, 15)
                frame = np.clip(frame + shift, 0, 255)

            # noise
            if random.random() < 0.2:
                noise = np.random.normal(0, 5, frame.shape)
                frame = np.clip(frame + noise, 0, 255)

        frames_list.append(frame)

    video_reader.release()
    return frames_list

# %% [markdown]
# ## Load all train data in train01.txt

# %%
from tqdm import tqdm
import numpy as np
import random
def load_videos(video_paths, labels=None, sequence_length=SEQUENCE_LENGTH, img_size=IMG_SIZE):
    """
    Load videos into numpy arrays with feature extraction and optional labels.
    Returns:
        X: np.array of shape (num_videos, sequence_length, H, W, 3)
        y: np.array of labels (if provided)
    """
    X = []
    y = [] if labels is not None else None

    for i, video_path in enumerate(tqdm(video_paths, desc="Loading videos")):
        frames = feature_extraction(video_path, augment=True)
        X.append(frames)
        if labels is not None:
            y.append(labels[i])

    X = np.array(X)
    if labels is not None:
        y = np.array(y)
        return X, y
    return X

# Example usage
x_all, y_all = load_videos(train_full_path, train_labels)

# Train-validation split
x_train_manual, x_val_manual, y_train_manual, y_val_manual = train_test_split(
    x_all, y_all, test_size=0.2, random_state=42, stratify=y_all
)
# Out:
# Loading videos: 100%|██████████| 9537/9537 [23:13<00:00,  6.84it/s]

# %% [markdown]
# ## Load all train data in test01.txt

# %%
def load_test_videos(video_paths, class_to_index, sequence_length=SEQUENCE_LENGTH, img_size=IMG_SIZE):
    """
    Load test videos into numpy arrays with feature extraction and labels.
    Returns:
        X_test: np.array of shape (num_videos, sequence_length, H, W, 3)
        y_test: np.array of labels
    """
    X_test = []
    y_test = []

    for video_path in tqdm(video_paths, desc="Loading test videos"):
        class_name = os.path.basename(os.path.dirname(video_path))
        label = class_to_index[class_name]
        frames = feature_extraction(video_path, augment=False)
        X_test.append(frames)
        y_test.append(label)

    X_test = np.array(X_test)
    y_test = np.array(y_test)
    return X_test, y_test

# Example usage
x_test, y_test = load_test_videos(test_full_path, class_to_index)
# Out:
# Loading test videos: 100%|██████████| 3783/3783 [08:13<00:00,  7.66it/s]

# %% [markdown]
# ## The Proposal model: CNN + LSTM (ConvLSTM2D)

# %%
# Build model
def build_model_mobilenet_lstm():
    inputs = Input(shape=(SEQUENCE_LENGTH, IMG_SIZE[0], IMG_SIZE[1], 3))

    base_cnn = MobileNetV2(
        include_top=False,
        weights="imagenet",
        pooling=None
    )
    base_cnn.trainable = False

    # Preprocess inside model
    x = TimeDistributed(Lambda(preprocess_input))(inputs)

    # Apply CNN on each frame
    x = TimeDistributed(base_cnn)(x)
    x = TimeDistributed(GlobalAveragePooling2D())(x)

    # Temporal modeling with LSTM
     #  Stronger regularization (fixes test accuracy crash)
    x = LSTM(
        128,
        return_sequences=False,
        dropout=0.3,
        recurrent_dropout=0.3,
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    )(x)

    x = Dense(128, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    outputs = Dense(NUM_CLASSES, activation='softmax')(x)
    return Model(inputs, outputs)


# def build_model(input_shape):
#     model = Sequential()
#     model.add(BatchNormalization(momentum=0.8, input_shape=input_shape))
#     model.add(ConvLSTM2D(16, (3,3), activation=LeakyReLU(), return_sequences=True, recurrent_dropout=0.2))
#     model.add(MaxPooling3D((1,2,2), padding='same'))
#     model.add(TimeDistributed(Dropout(0.4)))

#     model.add(ConvLSTM2D(16, (3,3), activation=LeakyReLU(), return_sequences=True, recurrent_dropout=0.2))
#     model.add(BatchNormalization(momentum=0.8))
#     model.add(MaxPooling3D((1,2,2), padding='same'))
#     model.add(TimeDistributed(Dropout(0.4)))

#     model.add(Flatten())
#     model.add(BatchNormalization())
#     model.add(Dense(256, activation="relu"))   # reduced size
#     model.add(Dropout(0.5))
#     model.add(Dense(NUM_CLASSES, activation="softmax"))
#     return model

# %% [markdown]
# # Callbacks

# %%
# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# %%
import time

# define dictionaries BEFORE training
histories = {}
times = {}

# %% [markdown]
# **➤ 3. Train with Adagrad**

# %%
model_ada = build_model_mobilenet_lstm()

model_ada.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adagrad(learning_rate=0.01),
    metrics=['accuracy']
)
start = time.time()

history_ada = model_ada.fit(
       x_train_manual, y_train_manual,
    validation_data=(x_val_manual, y_val_manual),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop, reduce_lr],
)
end = time.time()

histories["Adagrad"] = history_ada
times["Adagrad"] = end - start
# Out:
# /tmp/ipykernel_12/1450207719.py:5: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_cnn = MobileNetV2(
# 2025-12-05 22:51:15.611277: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 135s 399ms/step - accuracy: 0.0561 - loss: 4.6279 - val_accuracy: 0.1515 - val_loss: 4.0566 - learning_rate: 0.0100
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.1570 - loss: 3.8134 - val_accuracy: 0.3171 - val_loss: 3.2758 - learning_rate: 0.0100
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.2329 - loss: 3.3888 - val_accuracy: 0.3810 - val_loss: 2.8863 - learning_rate: 0.0100
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.2974 - loss: 3.1054 - val_accuracy: 0.4271 - val_loss: 2.6158 - learning_rate: 0.0100
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.3386 - loss: 2.8535 - val_accuracy: 0.4759 - val_loss: 2.4373 - learning_rate: 0.0100
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.3868 - loss: 2.6626 - val_accuracy: 0.5021 - val_loss: 2.2535 - learning_rate: 0.0100
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.4209 - loss: 2.4808 - val_accuracy: 0.5236 - val_loss: 2.1321 - learning_rate: 0.0100
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.4510 - loss: 2.3381 - val_accuracy: 0.5556 - val_loss: 1.9935 - learning_rate: 0.0100
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.4774 - loss: 2.2082 - val_accuracy: 0.5592 - val_loss: 1.8960 - learning_rate: 0.0100
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.5033 - loss: 2.0971 - val_accuracy: 0.5912 - val_loss: 1.8014 - learning_rate: 0.0100
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.5286 - loss: 1.9784 - val_accuracy: 0.6074 - val_loss: 1.7151 - learning_rate: 0.0100
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.5452 - loss: 1.9120 - val_accuracy: 0.6190 - val_loss: 1.6506 - learning_rate: 0.0100
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.5729 - loss: 1.8153 - val_accuracy: 0.6300 - val_loss: 1.5837 - learning_rate: 0.0100
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.5813 - loss: 1.7504 - val_accuracy: 0.6389 - val_loss: 1.5319 - learning_rate: 0.0100
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.5979 - loss: 1.6770 - val_accuracy: 0.6546 - val_loss: 1.4847 - learning_rate: 0.0100
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.6207 - loss: 1.5829 - val_accuracy: 0.6578 - val_loss: 1.4517 - learning_rate: 0.0100
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.6319 - loss: 1.5299 - val_accuracy: 0.6714 - val_loss: 1.3992 - learning_rate: 0.0100
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.6465 - loss: 1.4709 - val_accuracy: 0.6787 - val_loss: 1.3527 - learning_rate: 0.0100
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.6639 - loss: 1.4119 - val_accuracy: 0.6861 - val_loss: 1.3221 - learning_rate: 0.0100
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.6702 - loss: 1.3748 - val_accuracy: 0.6923 - val_loss: 1.2842 - learning_rate: 0.0100
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.6845 - loss: 1.3215 - val_accuracy: 0.6992 - val_loss: 1.2651 - learning_rate: 0.0100
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.6968 - loss: 1.2692 - val_accuracy: 0.7018 - val_loss: 1.2218 - learning_rate: 0.0100
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7093 - loss: 1.2282 - val_accuracy: 0.7034 - val_loss: 1.2149 - learning_rate: 0.0100
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.7158 - loss: 1.1909 - val_accuracy: 0.7117 - val_loss: 1.1830 - learning_rate: 0.0100
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7262 - loss: 1.1611 - val_accuracy: 0.7149 - val_loss: 1.1679 - learning_rate: 0.0100
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7306 - loss: 1.1172 - val_accuracy: 0.7238 - val_loss: 1.1353 - learning_rate: 0.0100
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.7355 - loss: 1.0820 - val_accuracy: 0.7301 - val_loss: 1.1162 - learning_rate: 0.0100
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7426 - loss: 1.0645 - val_accuracy: 0.7374 - val_loss: 1.0984 - learning_rate: 0.0100
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7478 - loss: 1.0503 - val_accuracy: 0.7332 - val_loss: 1.0893 - learning_rate: 0.0100
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.7565 - loss: 0.9983 - val_accuracy: 0.7390 - val_loss: 1.0770 - learning_rate: 0.0100
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7684 - loss: 0.9721 - val_accuracy: 0.7400 - val_loss: 1.0599 - learning_rate: 0.0100
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7724 - loss: 0.9518 - val_accuracy: 0.7479 - val_loss: 1.0421 - learning_rate: 0.0100
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.7780 - loss: 0.9198 - val_accuracy: 0.7474 - val_loss: 1.0308 - learning_rate: 0.0100
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.7835 - loss: 0.8980 - val_accuracy: 0.7490 - val_loss: 1.0116 - learning_rate: 0.0100
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.7933 - loss: 0.8757 - val_accuracy: 0.7516 - val_loss: 0.9931 - learning_rate: 0.0100
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.7968 - loss: 0.8478 - val_accuracy: 0.7521 - val_loss: 1.0005 - learning_rate: 0.0100
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.7932 - loss: 0.8599 - val_accuracy: 0.7594 - val_loss: 0.9840 - learning_rate: 0.0100
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 328ms/step - accuracy: 0.8077 - loss: 0.8198 - val_accuracy: 0.7600 - val_loss: 0.9780 - learning_rate: 0.0100
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8063 - loss: 0.8134 - val_accuracy: 0.7594 - val_loss: 0.9658 - learning_rate: 0.0100
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.8175 - loss: 0.7867 - val_accuracy: 0.7704 - val_loss: 0.9586 - learning_rate: 0.0100
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8154 - loss: 0.7680 - val_accuracy: 0.7636 - val_loss: 0.9503 - learning_rate: 0.0100
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8271 - loss: 0.7483 - val_accuracy: 0.7683 - val_loss: 0.9422 - learning_rate: 0.0100
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8266 - loss: 0.7352 - val_accuracy: 0.7699 - val_loss: 0.9403 - learning_rate: 0.0100
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 330ms/step - accuracy: 0.8363 - loss: 0.7019 - val_accuracy: 0.7804 - val_loss: 0.9278 - learning_rate: 0.0100
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8410 - loss: 0.7008 - val_accuracy: 0.7715 - val_loss: 0.9351 - learning_rate: 0.0100
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8393 - loss: 0.6816 - val_accuracy: 0.7668 - val_loss: 0.9208 - learning_rate: 0.0100
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8486 - loss: 0.6549 - val_accuracy: 0.7741 - val_loss: 0.9081 - learning_rate: 0.0100
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 328ms/step - accuracy: 0.8422 - loss: 0.6659 - val_accuracy: 0.7715 - val_loss: 0.9299 - learning_rate: 0.0100
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8544 - loss: 0.6532 - val_accuracy: 0.7778 - val_loss: 0.9176 - learning_rate: 0.0100
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 329ms/step - accuracy: 0.8422 - loss: 0.6550 - val_accuracy: 0.7752 - val_loss: 0.9087 - learning_rate: 0.0100

# %%
y_pred = np.argmax(model_ada.predict(x_test), axis=1)
test_acc = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_acc)
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 49s 332ms/step
# Test Accuracy: 0.40655564366904573

# %%
# history_ada=histories["Adagrad"]
# times["Adagrad"] = end - start

# %% [markdown]
# # Mobel train time

# %%
# # histories["Adagrad"] = history_ada
# times["Adagrad"] = end - start

# %%
for opt, t in times.items():
    print(f"{opt}: {t:.2f} seconds")
# Out:
# Adagrad: 4007.17 seconds

# %% [markdown]
# # ploting accuracy and Val_accuracy

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

for name, history in histories.items():
    plt.plot(history.history['accuracy'], label=f'{name} Train')
    plt.plot(history.history['val_accuracy'], label=f'{name} Val')

plt.title("Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Plot accuracy curves:**

# %% [markdown]
# # Plot loss curves:

# %%
plt.figure(figsize=(10,5))

for name, history in histories.items():
    plt.plot(history.history['loss'], label=f'{name} Train')
    plt.plot(history.history['val_loss'], label=f'{name} Val')

plt.title("Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Adam Test Accuracy

# %%
print("Adagrad Test Accuracy:", model_ada.evaluate(x_test, y_test))
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 30s 255ms/step - accuracy: 0.4066 - loss: 2.8108
# Adagrad Test Accuracy: [2.8108415603637695, 0.4065556526184082]

# %%
import numpy as np
from sklearn.metrics import accuracy_score

test_accuracies = {}
test_predictions = {}


# -----------------------
# 🟢 3) ADAGRAD
# -----------------------
y_pred_ada = model_ada.predict(x_test)
pred_class_ada = np.argmax(y_pred_ada, axis=1)

acc_ada = accuracy_score(y_test, pred_class_ada)
test_accuracies["Adagrad"] = acc_ada
test_predictions["Adagrad"] = pred_class_ada

print("Adagrad Test Accuracy:", acc_ada)
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 28s 237ms/step
# Adagrad Test Accuracy: 0.40655564366904573

# %%
import random
import os
import cv2

plt.figure(figsize=(30, 30))

all_classes_names = label_data.labels.values

random_classes = random.sample(list(all_classes_names), 8)

for i, class_name in enumerate(random_classes, 1):

    video_files = os.listdir(f'/kaggle/input/ucf101/UCF101/UCF-101/{class_name}')
    selected_video = random.choice(video_files)

    video_reader = cv2.VideoCapture(
        f'/kaggle/input/ucf101/UCF101/UCF-101/{class_name}/{selected_video}'
    )

    _, frame = video_reader.read()
    video_reader.release()

    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    cv2.putText(frame, class_name, (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)

    plt.subplot(4, 2, i)
    plt.imshow(frame)
    plt.axis("off")

# %% [markdown]
# # confusion Matrix

# %%
#Confusion Matrix
plt.figure(figsize=(25,25))
plt.title("Confusion matrix")
cm=confusion_matrix(y_test, y_pred)
plt.imshow(cm)
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment="center")
plt.show()

# %% [markdown]
# # save the tained model

# %%
# Save the trained model Adam_optimizer

# Save the trained model Adagrad_optimizer
model_ada.save('Action_Recognition_model_Adagrad_optimizer.keras')
print("Model saved to Action Recognition_model_Adagrad_optimizer.keras")
# Out:
# Model saved to Action Recognition_model_Adagrad_optimizer.keras

# %%
import cv2
import numpy as np

IMG_SIZE = 128
SEQ_LEN = 10   # must match your training

def preprocess_video(video_path, seq_len=SEQ_LEN):
    frames = []

    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    interval = max(1, total // seq_len)

    for i in range(seq_len):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * interval)
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.resize(frame, (IMG_SIZE, IMG_SIZE))
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = frame.astype("float32") / 255.0
        frames.append(frame)

    cap.release()

    frames = np.array(frames)

    if frames.shape[0] < seq_len:
        pad_len = seq_len - frames.shape[0]
        pad = np.zeros((pad_len, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate([frames, pad], axis=0)

    return frames.reshape(1, seq_len, IMG_SIZE, IMG_SIZE, 3)

# %%
def predict_action(model, video_path, class_names):
    frames = preprocess_video(video_path)
    preds = model.predict(frames)
    pred_idx = np.argmax(preds)
    return class_names[pred_idx], pred_idx, preds

# %%
# Example: your label list (already used in training)
class_names = label_data.labels.values

test_video = "/kaggle/input/ucf101/UCF101/UCF-101/PullUps/v_PullUps_g01_c01.avi"


action_name, idx, raw_probs = predict_action(model_ada, test_video, class_names)

print("Predicted Action:", action_name)
print("Class Index:", idx)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted Action: PullUps
# Class Index: 69
